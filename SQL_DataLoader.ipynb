# %%
import Importer  # Help directly import Ipython notebooks
# (Reference: https://nbviewer.jupyter.org/github/jupyter/notebook/blob/master/docs/source/examples/Notebook/Importing%20Notebooks.ipynb)
import Tushare_data_fetcher
import pymysql
import tushare as ts
import numpy as np
import pandas as pd
import sqlalchemy
import statsmodels.formula.api
import scipy
import datetime
import json
# Out:
# importing Jupyter notebook from Tushare_data_fetcher.ipynb

# %%
class DataLoader:
    def __init__(self):
        # pymysql
        with open('../config/config.json', 'r') as f:
            config = json.load(f)
        con = pymysql.connect(**config)
        cur = con.cursor()

        # sqlalchemy
        alchemy_str = 'mysql+pymysql://' + config['user'] + ':' + config[
            'password'] + '@' + config['host'] + ':' + str(
                config['port']) + '/' + config['database']
        self.alchemy_engine = sqlalchemy.create_engine(alchemy_str)

        # Get calendar dataframe for convenient date computation
        cal_query = '''
            SELECT DISTINCT trade_date
            FROM asset_return;
            '''
        cal_df = pd.read_sql_query(cal_query, con=self.alchemy_engine)
        cal_df = cal_df.sort_values(by=['trade_date'], ascending=False)
        self.cal_df = cal_df
        self.cal_df.reset_index(drop=True, inplace=True)
        # Str version for indexing
        cal_str_df = pd.DataFrame()
        cal_str_df['trade_date_str'] = cal_df['trade_date'].apply(
            lambda x: x.strftime('%Y-%m-%d'))
        self.cal_str_df = cal_str_df
        self.cal_str_df.reset_index(drop=True, inplace=True)
        # Store the latest date
        self.latest_date = self._get_latest_date()
        return

    def _get_latest_date(self, lag=0):  # Get latest date in database BARRA
        date_dt = self.cal_df.iloc[lag, 0]
        date = date_dt.strftime('%Y-%m-%d')
        print(f'Lastest date(lag = {lag} from today): {date}')
        return date

    def _get_query_end_date(self, lag=0):
        # Get an end date for query, so that record numbers fit the expectations
        if (lag == 0):
            dt = datetime.datetime.now()
            end_date = dt.strftime(
                '%Y-%m-%d'
            )  # Today would be a natural end date since it could never be accessed
        else:
            end_date = self._get_latest_date(lag=lag - 1)
        return end_date

    def _last_disclosure_date(self, nominal_end_date_dt):
        # Find an approriate query_date for balance query
        # Last disclosure date for 1Q 4.30
        # Last disclosure date for 1H 8.31
        # Last disclosure date for 3Q 10.31
        # Last disclosure date for 1Y 4.30(Next year)
        nominal_end_date = nominal_end_date_dt.strftime('%Y-%m-%d')
        nominal_end_year = nominal_end_date[:4]
        if (nominal_end_date.endswith('03-31')):
            last_disclosure_date = nominal_end_year + '-04-30'
        elif (nominal_end_date.endswith('06-30')):
            last_disclosure_date = nominal_end_year + '-08-31'
        elif (nominal_end_date.endswith('09-30')):
            last_disclosure_date = nominal_end_year + '-10-31'
        else:
            last_disclosure_date = str(int(nominal_end_year)+1) + '-04-30'
        return last_disclosure_date

    def _get_date_lag(self, date):
        lag = self.cal_str_df[self.cal_str_df['trade_date_str'] ==
                              date].index.to_list()[0]
        return lag

    def _standardize_date(self, date_str):  # Standardize for query
        date_dt = datetime.datetime.strptime(date_str, '%Y%m%d')
        standard_str = date_dt.strftime('%Y-%m-%d')
        return standard_str

    def _winsorize(self, data, limits=[0.01, 0.01]):
        data_winsorize = scipy.stats.mstats.winsorize(data, limits=limits)
        data_winsorize = data_winsorize.data
        return data_winsorize

    def _standardize(self, data):
        mu = np.mean(data)
        sigma = np.std(data)
        data_standardize = (data - mu) / sigma
        return data_standardize

    def get_daily_size(self, date=None):
        if date == None:  # Default: Get latest date
            date = self.latest_date
        else:
            date = self._standardize_date(date)
        query = f'''
            SELECT ts_code, total_mv
            FROM daily
            WHERE trade_date = \'{date}\';
            '''
        query_df = pd.read_sql_query(query, con=self.alchemy_engine)
        query_df['total_mv_exact'] = query_df['total_mv'] * 10000
        query_df['log_mv'] = np.log(query_df['total_mv_exact'])
        return_df = query_df[['ts_code', 'log_mv']].copy()
        return return_df

    def get_daily_book_to_price(self, date=None):
        if date == None:  # Default: Get latest date
            date = self.latest_date
        else:
            date = self._standardize_date(date)

        query = f'''
            SELECT ts_code, pb
            FROM daily
            WHERE trade_date = \'{date}\';
            '''
        query_df = pd.read_sql_query(query, con=self.alchemy_engine)
        # PB versus Book-to-Price
        query_df['book_to_price'] = query_df['pb'].apply(lambda x: 1 / x)
        return_df = query_df[['ts_code', 'book_to_price']].copy()
        return return_df

    def get_daily_nonlinear_size(self, date=None):
        if date == None:  # Default: Get latest date
            date = self.latest_date
        else:
            date = self._standardize_date(date)

        query = f'''
            SELECT ts_code, total_mv
            FROM daily
            WHERE trade_date = \'{date}\';
            '''
        query_df = pd.read_sql_query(query, con=self.alchemy_engine)
        query_df['total_mv_cube'] = query_df['total_mv'].apply(lambda x: x**3)
        # Linear regression
        size_model = statsmodels.formula.api.ols(
            formula='total_mv_cube ~ total_mv', data=query_df).fit()
        size_resid = size_model.resid
        # Winsorize and standardize
        size_resid_winsorize = self._winsorize(size_resid)
        size_resid_standardize = self._standardize(size_resid_winsorize)

        query_df['nonlinear_size'] = size_resid_standardize
        return_df = query_df[['ts_code', 'nonlinear_size']].copy()
        return return_df

    def get_daily_beta(self, date=None):
        if date == None:  # Default: Get latest date
            date = self.latest_date
        else:
            date = self._standardize_date(date)

        date_lag = self._get_date_lag(date)
        latest_date_252 = self._get_latest_date(lag=date_lag + 252)
        query_end_date = self._get_query_end_date(lag=date_lag)

        # Get all stock return from SQL into memory(read data from SQL is time-consuming)
        query_all_stock = f'''
            SELECT ts_code, pct_chg, trade_date
            FROM asset_return
            WHERE trade_date > \'{latest_date_252}\'
            AND trade_date < \'{query_end_date}\'
            AND ts_code <> '000985.CSI';
            '''
        all_stock_df = pd.read_sql_query(query_all_stock,
                                         con=self.alchemy_engine)
        # Get all stock_id
        all_stock_id_list = list(set(all_stock_df['ts_code'].to_list()))
        # Get risk-free return (shibor_on) during this period
        shibor_query = f'''
            SELECT `on`, date
            FROM shibor
            WHERE date > \'{latest_date_252}\'
            AND date < \'{query_end_date}\';
            '''
        shibor_df = pd.read_sql_query(shibor_query, con=self.alchemy_engine)
        shibor_df['daily_on'] = shibor_df['on'].apply(lambda x: (np.power(
            (1 + x / 100), 1 / 252) - 1) * 100)
        # Get market portfolio return (000985.CSI, alias mkp) during this period
        query_index = f'''
            SELECT pct_chg, trade_date
            FROM asset_return
            WHERE ts_code = '000985.CSI'
            AND trade_date > \'{latest_date_252}\'
            AND trade_date < \'{query_end_date}\';
            '''
        mkp_df = pd.read_sql_query(query_index, con=self.alchemy_engine)
        # Define a container for beta
        beta_container = []
        count = 1
        for stock_id in all_stock_id_list:
            stock_df = all_stock_df[all_stock_df['ts_code'] == stock_id].copy()
            ret_df = mkp_df.merge(right=stock_df,
                                  how='inner',
                                  on='trade_date',
                                  suffixes=['_stock', '_mkp'])
            if (ret_df.shape[0] < 126):  # Not enough records for computation
                print(
                    f'({count}/{len(all_stock_id_list)}) {stock_id} has inadequate records till {date}.'
                )
                count += 1
                beta_container.append([stock_id, np.nan])
                pass
            else:
                ret_df = ret_df.merge(right=shibor_df,
                                      how='inner',
                                      left_on='trade_date',
                                      right_on='date')
                ret_df = ret_df.sort_values(by=['trade_date'], ascending=False)
                # Weigh the excess return with EWMA weights (half-life = 63)
                half_life = 63
                alpha = np.power(0.5, 1 / half_life)
                weight = np.logspace(start=1, stop=252, num=252, base=alpha)
                record_num = ret_df.shape[0]
                weight = weight[:record_num]
                # Store weighed excess return series for regression
                reg_df = pd.DataFrame()
                reg_df['pct_chg_stock_excess'] = (ret_df['pct_chg_stock'] -
                                                  ret_df['daily_on'])
                reg_df['pct_chg_mkp_excess'] = ret_df['pct_chg_mkp'] - ret_df[
                    'daily_on']
                beta_model = statsmodels.formula.api.wls(
                    formula='pct_chg_stock_excess ~ pct_chg_mkp_excess',
                    data=reg_df,
                    weights=weight).fit()
                # Store the regression coefficients
                beta = beta_model.params['pct_chg_mkp_excess']
                print(
                    f'({count}/{len(all_stock_id_list)}) Adjusted beta of {stock_id} in {date} is {beta}.'
                )
                count += 1
                beta_container.append([stock_id, beta])
        return_df = pd.DataFrame(beta_container,
                                 columns=['ts_code', 'beta_raw'])
        return return_df

    def get_daily_momentum(self, date=None):
        if date == None:  # Default: Get latest date
            date = self.latest_date
        else:
            date = self._standardize_date(date)
        date_lag = self._get_date_lag(date)
        latest_date_526 = self._get_latest_date(lag=date_lag +
                                                526)  # 504 + 21 + 1
        latest_date_21 = self._get_latest_date(lag=date_lag + 21)
        query_all_stock = f'''
                    SELECT ts_code, pct_chg, trade_date
                    FROM asset_return
                    WHERE trade_date > \'{latest_date_526}\'
                    AND trade_date <= \'{latest_date_21}\'
                    AND ts_code <> '000985.CSI';
                    '''
        all_stock_df = pd.read_sql_query(query_all_stock,
                                         con=self.alchemy_engine)
        # Get all stock_id
        all_stock_id_list = list(set(all_stock_df['ts_code'].to_list()))
        # Get risk-free return (shibor_on) during this period
        shibor_query = f'''
            SELECT `on`, date
            FROM shibor
            WHERE date > \'{latest_date_526}\'
            AND date <= \'{latest_date_21}\';
            '''
        shibor_df = pd.read_sql_query(shibor_query, con=self.alchemy_engine)
        shibor_df['daily_on'] = shibor_df['on'].apply(lambda x: np.power(
            (1 + x / 100), 1 / 252) - 1)
        # Note that this 'daily_on' is computed without pct adjustment, considering its use in the formula
        momentum_container = []
        count = 1
        suc_count = 1  # Count stocks with enough records
        for stock_id in all_stock_id_list:
            stock_df = all_stock_df[all_stock_df['ts_code'] == stock_id].copy()
            stock_df['chg'] = stock_df['pct_chg'] / 100
            if (
                    stock_df.shape[0] < 500
            ):  # Inadequate records (Spare five days to get more useful data)
                momentum_container.append([stock_id, np.nan,
                                           0])  # No records are used
                print(
                    f'({count}/{len(all_stock_id_list)}) {stock_id} has inadequate records (only {stock_df.shape[0]}) till {date}.'
                )
                count += 1
                pass
            else:
                ret_df = stock_df.merge(right=shibor_df,
                                        how='inner',
                                        left_on='trade_date',
                                        right_on='date')
                ret_df = ret_df.sort_values(by=['trade_date'], ascending=False)
                ret_df['daily_RSTR'] = np.log(1 + ret_df['chg']) - np.log(
                    1 + ret_df['daily_on'])
                # Weigh the excess return with EWMA weights (half-life = 63)
                half_life = 126
                alpha = np.power(0.5, 1 / half_life)
                valid_days = ret_df.shape[0]
                weight = np.logspace(start=1,
                                     stop=valid_days,
                                     num=valid_days,
                                     base=alpha)
                # Compute RSTR
                RSTR = np.sum(ret_df['daily_RSTR'] * weight)
                momentum_container.append([stock_id, RSTR, valid_days])
                print(
                    f'({count}/{len(all_stock_id_list)}) RSTR of {stock_id} in {date} is {RSTR}. Current Success: {suc_count}'
                )
                count += 1
                suc_count += 1
        return_df = pd.DataFrame(
            momentum_container,
            columns=['ts_code', 'momentum_raw', 'valid_days_used'])
        return return_df

    def _get_daily_RV_HSIGMA(self, date=None):
        if date == None:  # Default: Get latest date
            date = self.latest_date
        else:
            date = self._standardize_date(date)

        date_lag = self._get_date_lag(date)
        latest_date_252 = self._get_latest_date(lag=date_lag + 252)
        query_end_date = self._get_query_end_date(lag=date_lag)
        # Get all stock return from SQL into memory(read data from SQL is time-consuming)
        query_all_stock = f'''
            SELECT ts_code, pct_chg, trade_date
            FROM asset_return
            WHERE trade_date > \'{latest_date_252}\'
            AND trade_date < \'{query_end_date}\'
            AND ts_code <> '000985.CSI';
            '''
        all_stock_df = pd.read_sql_query(query_all_stock,
                                         con=self.alchemy_engine)
        # Get all stock_id
        all_stock_id_list = list(set(all_stock_df['ts_code'].to_list()))
        # Get risk-free return (shibor_on) during this period
        shibor_query = f'''
            SELECT `on`, date
            FROM shibor
            WHERE date > \'{latest_date_252}\'
            AND date < \'{query_end_date}\';
            '''
        shibor_df = pd.read_sql_query(shibor_query, con=self.alchemy_engine)
        shibor_df['daily_on'] = shibor_df['on'].apply(lambda x: (np.power(
            (1 + x / 100), 1 / 252) - 1) * 100)
        # Get market portfolio return (000985.CSI, alias mkp) during this period
        query_index = f'''
            SELECT pct_chg, trade_date
            FROM asset_return
            WHERE ts_code = '000985.CSI'
            AND trade_date > \'{latest_date_252}\'
            AND trade_date < \'{query_end_date}\';
            '''
        mkp_df = pd.read_sql_query(query_index, con=self.alchemy_engine)
        # Define a container for beta
        HSIGMA_container = []  # Historical Sigma
        count = 1
        for stock_id in all_stock_id_list:
            stock_df = all_stock_df[all_stock_df['ts_code'] == stock_id].copy()
            ret_df = mkp_df.merge(right=stock_df,
                                  how='inner',
                                  on='trade_date',
                                  suffixes=['_stock', '_mkp'])
            if (ret_df.shape[0] < 126):  # Not enough records for computation
                print(
                    f'({count}/{len(all_stock_id_list)}) {stock_id} has inadequate records till {date}.'
                )
                count += 1
                HSIGMA_container.append([stock_id, np.nan])
                pass
            else:
                ret_df = ret_df.merge(right=shibor_df,
                                      how='inner',
                                      left_on='trade_date',
                                      right_on='date')
                ret_df = ret_df.sort_values(by=['trade_date'], ascending=False)
                # Weigh the excess return with EWMA weights (half-life = 63)
                half_life = 63
                alpha = np.power(0.5, 1 / half_life)
                weight = np.logspace(start=1, stop=252, num=252, base=alpha)
                record_num = ret_df.shape[0]
                weight = weight[:record_num]
                # Store weighed excess return series for regression
                reg_df = pd.DataFrame()
                reg_df['pct_chg_stock_excess'] = (ret_df['pct_chg_stock'] -
                                                  ret_df['daily_on'])
                reg_df['pct_chg_mkp_excess'] = ret_df['pct_chg_mkp'] - ret_df[
                    'daily_on']
                beta_model = statsmodels.formula.api.wls(
                    formula='pct_chg_stock_excess ~ pct_chg_mkp_excess',
                    data=reg_df,
                    weights=weight).fit()
                # Store the regression coefficients
                resid_ret = beta_model.resid
                resid_ret_sigma = np.std(resid_ret)
                print(
                    f'({count}/{len(all_stock_id_list)}) Volatility of residual return of {stock_id} in {date} is {resid_ret_sigma}.'
                )
                count += 1
                HSIGMA_container.append([stock_id, resid_ret_sigma])
        return_df = pd.DataFrame(HSIGMA_container,
                                 columns=['ts_code', 'HSIGMA_raw'])
        return return_df

    def _get_daily_RV_DASTD(self, date=None):
        if date == None:  # Default: Get latest date
            date = self.latest_date
        else:
            date = self._standardize_date(date)

        date_lag = self._get_date_lag(date)
        latest_date_252 = self._get_latest_date(lag=date_lag + 252)
        query_end_date = self._get_query_end_date(lag=date_lag)
        # Get all stock return from SQL into memory(read data from SQL is time-consuming)
        query_all_stock = f'''
            SELECT ts_code, pct_chg, trade_date
            FROM asset_return
            WHERE trade_date > \'{latest_date_252}\'
            AND trade_date < \'{query_end_date}\'
            AND ts_code <> '000985.CSI';
            '''
        all_stock_df = pd.read_sql_query(query_all_stock,
                                         con=self.alchemy_engine)
        # Get all stock_id
        all_stock_id_list = list(set(all_stock_df['ts_code'].to_list()))
        # Get risk-free return (shibor_on) during this period
        shibor_query = f'''
            SELECT `on`, date
            FROM shibor
            WHERE date > \'{latest_date_252}\'
            AND date < \'{query_end_date}\';
            '''
        shibor_df = pd.read_sql_query(shibor_query, con=self.alchemy_engine)
        shibor_df['daily_on'] = shibor_df['on'].apply(lambda x: (np.power(
            (1 + x / 100), 1 / 252) - 1) * 100)
        # Define a container
        DASTD_container = []
        count = 1
        for stock_id in all_stock_id_list:
            stock_df = all_stock_df[all_stock_df['ts_code'] == stock_id].copy()
            if (stock_df.shape[0] < 126):  # Not enough records for computation
                print(
                    f'({count}/{len(all_stock_id_list)}) {stock_id} has inadequate records till {date}.'
                )
                count += 1
                DASTD_container.append([stock_id, np.nan, np.nan])
                pass
            else:
                ret_df = stock_df.merge(right=shibor_df,
                                        how='inner',
                                        left_on='trade_date',
                                        right_on='date')
                ret_df = ret_df.sort_values(by=['trade_date'], ascending=False)
                # Weigh the excess return with EWMA weights (half-life = 63)
                half_life = 42
                alpha = np.power(0.5, 1 / half_life)
                weight = np.logspace(start=1, stop=252, num=252, base=alpha)
                record_num = ret_df.shape[0]
                weight = weight[:record_num]
                # Compute wighted standard deviation
                ret_df['daily_excessive_ret'] = (ret_df['pct_chg'] -
                                                 ret_df['daily_on']) / 100
                # Use the real return, rather than the pct form
                ret_df['ex_ret_temp'] = np.square(
                    ret_df['daily_excessive_ret'] -
                    np.mean(ret_df['daily_excessive_ret']))
                DASTD = np.mean(weight * ret_df['ex_ret_temp'])
                DASTD_2 = np.std(ret_df['daily_excessive_ret'] * weight)
                print(
                    f'({count}/{len(all_stock_id_list)}) Volatility of daily excessive return of {stock_id} in {date} is {DASTD}.'
                )
                count += 1
                DASTD_container.append([stock_id, DASTD, DASTD_2])
        return_df = pd.DataFrame(
            DASTD_container,
            columns=['ts_code', 'DASTD_raw', 'DASTD_weighed_ret_raw'])
        return return_df

    def _get_daily_RV_CMRA(self, date=None):
        if date == None:  # Default: Get latest date
            date = self.latest_date
        else:
            date = self._standardize_date(date)

        date_lag = self._get_date_lag(date)
        latest_date_252 = self._get_latest_date(lag=date_lag + 252)
        query_end_date = self._get_query_end_date(lag=date_lag)
        # Get all stock return from SQL into memory(read data from SQL is time-consuming)
        query_all_stock = f'''
            SELECT ts_code, pct_chg, trade_date
            FROM asset_return
            WHERE trade_date > \'{latest_date_252}\'
            AND trade_date < \'{query_end_date}\'
            AND ts_code <> '000985.CSI';
            '''
        all_stock_df = pd.read_sql_query(query_all_stock,
                                         con=self.alchemy_engine)
        # Get all stock_id
        all_stock_id_list = list(set(all_stock_df['ts_code'].to_list()))
        # Get risk-free return (shibor_on) during this period
        shibor_query = f'''
            SELECT `on`, date
            FROM shibor
            WHERE date > \'{latest_date_252}\'
            AND date < \'{query_end_date}\';
            '''
        shibor_df = pd.read_sql_query(shibor_query, con=self.alchemy_engine)
        shibor_df['daily_on'] = shibor_df['on'].apply(lambda x: (np.power(
            (1 + x / 100), 1 / 252) - 1))  # Not use the pct form
        # Define a container
        CMRA_container = []
        count = 1
        for stock_id in all_stock_id_list:
            stock_df = all_stock_df[all_stock_df['ts_code'] == stock_id].copy()
            if (stock_df.shape[0] != 252):
                # Not enough records for computation
                print(
                    f'({count}/{len(all_stock_id_list)}) {stock_id} has inadequate records till {date}.'
                )
                count += 1
                CMRA_container.append([stock_id, np.nan])
                pass
            else:
                ret_df = stock_df.merge(right=shibor_df,
                                        how='inner',
                                        left_on='trade_date',
                                        right_on='date')
                ret_df['chg'] = ret_df['pct_chg'] / 100  # Not use the pct form
                ret_df = ret_df.sort_values(by=['trade_date'], ascending=False)
                monthly_excessive_ret_list = []
                for month in range(1, 13):
                    month_ret_df = ret_df.iloc[21 * (month - 1):21 *
                                               month, :].copy()
                    month_ret_df['log_ret'] = np.log(1 + month_ret_df['chg'])
                    month_ret_df['log_risk_free'] = np.log(
                        1 + month_ret_df['daily_on'])
                    month_ret = np.sum(month_ret_df['log_ret'])
                    month_risk_free = np.sum(month_ret_df['log_risk_free'])
                    monthly_excessive_ret_list.append(month_ret -
                                                      month_risk_free)
                Z_list = np.cumsum(monthly_excessive_ret_list)
                CMRA = np.max(Z_list) - np.min(Z_list)
                print(
                    f'({count}/{len(all_stock_id_list)}) CMRA of {stock_id} in {date} is {CMRA}.'
                )
                count += 1
                CMRA_container.append([stock_id, CMRA])
        return_df = pd.DataFrame(CMRA_container,
                                 columns=['ts_code', 'CMRA_raw'])
        return return_df

    def get_daily_residual_volatility(self, date=None):
        RV_HSIGMA_df = self._get_daily_RV_HSIGMA(date)
        RV_CMRA_df = self._get_daily_RV_CMRA(date)
        RV_DASTD_df = self._get_daily_RV_DASTD(date)
        RV_df = RV_HSIGMA_df.merge(right=RV_CMRA_df, on='ts_code', how='outer', validate = '1:1')
        RV_df = RV_df.merge(right=RV_DASTD_df, on='ts_code', how='outer', validate = '1:1')
        return RV_df

    def get_daily_liquidity(self, date=None):
        if date == None:  # Default: Get latest date
            date = self.latest_date
        else:
            date = self._standardize_date(date)

        date_lag = self._get_date_lag(date)
        latest_date_252 = self._get_latest_date(lag=date_lag + 252)
        query_end_date = self._get_query_end_date(lag=date_lag)
        query_all_stock = f'''
        SELECT ts_code, trade_date, turnover_rate_f
        FROM daily
        WHERE trade_date > \'{latest_date_252}\'
        AND trade_date < \'{query_end_date}\';
        '''
        all_stock_df = pd.read_sql_query(query_all_stock,
                                         con=self.alchemy_engine)
        # Get all stock_id
        all_stock_id_list = list(set(all_stock_df['ts_code'].to_list()))
        # Get all stock_id
        liquidity_container = []
        count = 1
        for stock_id in all_stock_id_list:
            stock_df = all_stock_df[all_stock_df['ts_code'] == stock_id].copy()
            if (stock_df.shape[0] != 252):
                # Not enough records for computation
                print(
                    f'({count}/{len(all_stock_id_list)}) {stock_id} has inadequate records till {date}.'
                )
                count += 1
                liquidity_container.append([stock_id, np.nan, np.nan, np.nan])
                pass
            else:
                STOM_list = []
                for month in range(1, 13):
                    month_df = stock_df.iloc[21 * (month - 1):21 *
                                             month, :].copy()
                    STOM = np.log(np.sum(month_df['turnover_rate_f']))
                    STOM_list.append(STOM)
                STOM = STOM_list[0]
                # STOQ
                STOM_3 = STOM_list[:3]
                STOQ = np.log(np.mean(np.exp(STOM_3)))
                # STOA
                STOA = np.log(np.mean(np.exp(STOM_list)))
                print(
                    f'({count}/{len(all_stock_id_list)}) STOM: {STOM}, STOQ: {STOQ}, STOA: {STOA}.'
                )
                count += 1
                liquidity_container.append([stock_id, STOM, STOQ, STOA])
        return_df = pd.DataFrame(liquidity_container,
                                 columns=['ts_code', 'STOM', 'STOQ', 'STOA'])
        return return_df

    def get_daily_leverage(self, date=None):
        if date == None:  # Default: Get latest date
            date = self.latest_date
        else:
            date = self._standardize_date(date)

        query = f'''
            SELECT DISTINCT end_date
            FROM balance;
            '''
        report_date_df = pd.read_sql_query(query, con=self.alchemy_engine)
        report_date_df['last_disclosure_date'] = report_date_df['end_date'].apply(
            lambda x: self._last_disclosure_date(x))
        row_index = np.sum(report_date_df['last_disclosure_date'] < date) - 1
        valid_last_date = report_date_df.iloc[row_index, 0].strftime(
            '%Y-%m-%d')
        print(f'{date}: Use {valid_last_date} for query.')
        balance_query = f'''
            SELECT ts_code,end_date, total_share,total_assets,total_cur_liab,total_liab,oth_eqt_tools_p_shr
            FROM balance
            WHERE end_date = \'{valid_last_date}\';
            '''
        bal_df = pd.read_sql_query(balance_query, con=self.alchemy_engine)

        cap_query = f'''
            SELECT ts_code, total_mv
            FROM daily
            WHERE trade_date = \'{date}\';
            '''
        cap_df = pd.read_sql_query(cap_query, con=self.alchemy_engine)
        cap_df['total_mv_real'] = cap_df['total_mv'] * 10000

        df = bal_df.merge(right=cap_df, how='inner', on='ts_code')
        df = df.fillna(0)  # only affecting total_cur_liab and preferred_stock
        df['long_liab'] = df['total_liab'] - df['total_cur_liab']
        df['MLEV'] = (df['total_mv_real'] + df['oth_eqt_tools_p_shr'] +
                      df['long_liab']) / df['total_mv_real']
        df['DTOA'] = df['total_liab'] / df['total_assets']
        df['BLEV'] = (df['total_share'] + df['oth_eqt_tools_p_shr'] +
                      df['long_liab']) / df['total_share']
        df['leverage_raw'] = 0.38 * df['MLEV'] + \
            0.35 * df['DTOA'] + 0.27 * df['BLEV']

        return_df = df[['ts_code', 'leverage_raw']].copy()
        return return_df

    def get_daily_earnings_yield(self, date=None):
        if date == None:  # Default: Get latest date
            date = self.latest_date
        else:
            date = self._standardize_date(date)
            
        # EPIBS
        est_pe_query = '''
                    SELECT 
                    '''

# %% [markdown]
# ## Test

# %%
Loader = DataLoader()
# Out:
# Lastest date(lag = 0 from today): 2021-09-03

# %%
RV_df = Loader.get_daily_residual_volatility()
# Out:
# Lastest date(lag = 252 from today): 2020-08-24
# (1/4474) Volatility of residual return of 688222.SH in 2021-09-03 is 1.0170663740875647.
# (2/4474) Volatility of residual return of 601518.SH in 2021-09-03 is 1.0659603147736503.
# (3/4474) Volatility of residual return of 300622.SZ in 2021-09-03 is 1.0807257907949066.
# (4/4474) Volatility of residual return of 000031.SZ in 2021-09-03 is 1.084714160662398.
# (5/4474) Volatility of residual return of 601899.SH in 2021-09-03 is 0.9486583393187875.
# (6/4474) Volatility of residual return of 300623.SZ in 2021-09-03 is 1.0133355728048474.
# (7/4474) Volatility of residual return of 300855.SZ in 2021-09-03 is 1.080136431293269.
# (8/4474) Volatility of residual return of 003027.SZ in 2021-09-03 is 1.1147509818384187.
# (9/4474) Volatility of residual return of 600100.SH in 2021-09-03 is 1.0511489226511408.
# (10/4474) Volatility of residual return of 600475.SH in 2021-09-03 is 1.0550851295081616.
# (11/4474) 601528.SH has inadequate records till 2021-09-03.
# (12/4474) Volatility of residual return of 601928.SH in 2021-09-03 is 1.1090734449457844.
# (13/4474) Volatility of residual return of 300662.SZ in 2021-09-03 is 1.0598602941744806.
# (14/4474) Volatility of residual return of 002628.SZ in 2021-09-03 is 1.0295908277566521.
# (15/4474) Volatility of residual return of 600681.SH in 2021-09-03 is 1.067981439785374.
# (16/4474) Volatility of residual return of 002656.SZ in 2021-09-03 is 1.1088081168671857.
# (17/4474) Volatility of residual return of 688080.SH in 2021-09-03 is 1.0772884147543498.
# (18/4474) Volatility of residual return of 000023.SZ in 2021-09-03 is 1.0504201929786072.
# (19/4474) Volatility of residual return of 603866.SH in 2021-09-03 is 1.066011816198556.
# (20/4474) Volatility of residual return of 600581.SH in 2021-09-03 is 1.0719058102998595.
# (21/4474) Volatility of residual return of 601666.SH in 2021-09-03 is 1.0716312346257562.
# (22/4474) Volatility of residual return of 600867.SH in 2021-09-03 is 1.047651445643914.
# (23/4474) Volatility of residual return of 600665.SH in 2021-09-03 is 1.0724600409189764.
# (24/4474) Volatility of residual return of 000046.SZ in 2021-09-03 is 1.1029728781923465.
# (25/4474) Volatility of residual return of 000892.SZ in 2021-09-03 is 1.0820268702002775.
# (26/4474) Volatility of residual return of 300873.SZ in 2021-09-03 is 1.0906610679541016.
# (27/4474) Volatility of residual return of 600513.SH in 2021-09-03 is 1.0638980951835137.
# (28/4474) Volatility of residual return of 300577.SZ in 2021-09-03 is 1.0430715669908472.
# (29/4474) Volatility of residual return of 300946.SZ in 2021-09-03 is 1.1046833844447244.
# (30/4474) 301026.SZ has inadequate records till 2021-09-03.
# (31/4474) Volatility of residual return of 300232.SZ in 2021-09-03 is 1.0354484866622713.
# (32/4474) Volatility of residual return of 300319.SZ in 2021-09-03 is 1.0670539742821818.
# (33/4474) Volatility of residual return of 600759.SH in 2021-09-03 is 1.092931619336477.
# (34/4474) Volatility of residual return of 300094.SZ in 2021-09-03 is 1.079447601145289.
# (35/4474) Volatility of residual return of 603159.SH in 2021-09-03 is 1.0682062379863917.
# (36/4474) Volatility of residual return of 600289.SH in 2021-09-03 is 1.0992932970983043.
# (37/4474) Volatility of residual return of 300781.SZ in 2021-09-03 is 1.115416743564431.
# (38/4474) Volatility of residual return of 600373.SH in 2021-09-03 is 1.0546473927553823.
# (39/4474) Volatility of residual return of 603169.SH in 2021-09-03 is 1.0954484822052717.
# (40/4474) Volatility of residual return of 600141.SH in 2021-09-03 is 0.9919542223937389.
# (41/4474) Volatility of residual return of 603160.SH in 2021-09-03 is 1.043062848512854.
# (42/4474) Volatility of residual return of 300259.SZ in 2021-09-03 is 1.0144369465182332.
# (43/4474) Volatility of residual return of 300775.SZ in 2021-09-03 is 0.9844402996090089.
# (44/4474) Volatility of residual return of 601226.SH in 2021-09-03 is 1.065286987688324.
# (45/4474) 688216.SH has inadequate records till 2021-09-03.
# (46/4474) Volatility of residual return of 002531.SZ in 2021-09-03 is 1.0328069358882506.
# (47/4474) 603171.SH has inadequate records till 2021-09-03.
# (48/4474) Volatility of residual return of 603267.SH in 2021-09-03 is 1.0090969571174846.
# (49/4474) Volatility of residual return of 603357.SH in 2021-09-03 is 0.9842111138041114.
# (50/4474) Volatility of residual return of 600552.SH in 2021-09-03 is 1.027824550684796.
# (51/4474) Volatility of residual return of 000858.SZ in 2021-09-03 is 0.8481907049382431.
# (52/4474) Volatility of residual return of 300181.SZ in 2021-09-03 is 1.0647857274673904.
# (53/4474) Volatility of residual return of 002216.SZ in 2021-09-03 is 1.036901639026703.
# (54/4474) Volatility of residual return of 600076.SH in 2021-09-03 is 1.093500686085815.
# (55/4474) Volatility of residual return of 002349.SZ in 2021-09-03 is 1.066931593742146.
# (56/4474) Volatility of residual return of 000901.SZ in 2021-09-03 is 0.9896827389508107.
# (57/4474) 688083.SH has inadequate records till 2021-09-03.
# (58/4474) Volatility of residual return of 603721.SH in 2021-09-03 is 1.0663718077821969.
# (59/4474) 000792.SZ has inadequate records till 2021-09-03.
# (60/4474) Volatility of residual return of 603229.SH in 2021-09-03 is 1.068461327990469.
# (61/4474) Volatility of residual return of 300036.SZ in 2021-09-03 is 1.068287075532654.
# (62/4474) Volatility of residual return of 000626.SZ in 2021-09-03 is 1.1087453450649238.
# (63/4474) Volatility of residual return of 300736.SZ in 2021-09-03 is 1.0532659141929395.
# (64/4474) Volatility of residual return of 603616.SH in 2021-09-03 is 1.0853142723509417.
# (65/4474) Volatility of residual return of 002132.SZ in 2021-09-03 is 1.0545818230877828.
# (66/4474) Volatility of residual return of 002849.SZ in 2021-09-03 is 1.045227675414813.
# (67/4474) Volatility of residual return of 600861.SH in 2021-09-03 is 1.0975184660793897.
# (68/4474) Volatility of residual return of 300127.SZ in 2021-09-03 is 1.0501579701258608.
# (69/4474) Volatility of residual return of 300693.SZ in 2021-09-03 is 1.0499032589064758.
# (70/4474) Volatility of residual return of 000557.SZ in 2021-09-03 is 1.0667137187064697.
# (71/4474) Volatility of residual return of 603226.SH in 2021-09-03 is 1.0978690379541431.
# (72/4474) Volatility of residual return of 300534.SZ in 2021-09-03 is 1.0730793716400604.
# (73/4474) Volatility of residual return of 688510.SH in 2021-09-03 is 1.1161684905452787.
# (74/4474) Volatility of residual return of 601212.SH in 2021-09-03 is 1.0498556165240727.
# (75/4474) Volatility of residual return of 603029.SH in 2021-09-03 is 1.033632641919853.
# (76/4474) Volatility of residual return of 300011.SZ in 2021-09-03 is 1.0403984854432655.
# (77/4474) Volatility of residual return of 300464.SZ in 2021-09-03 is 1.0507034335819943.
# (78/4474) Volatility of residual return of 688118.SH in 2021-09-03 is 1.0385622355601516.
# (79/4474) Volatility of residual return of 300586.SZ in 2021-09-03 is 1.0315360559333995.
# (80/4474) Volatility of residual return of 300263.SZ in 2021-09-03 is 1.0237813560489604.
# (81/4474) Volatility of residual return of 600271.SH in 2021-09-03 is 1.0277480608330822.
# (82/4474) 688269.SH has inadequate records till 2021-09-03.
# (83/4474) 300980.SZ has inadequate records till 2021-09-03.
# (84/4474) Volatility of residual return of 300272.SZ in 2021-09-03 is 1.0529410435184268.
# (85/4474) 301004.SZ has inadequate records till 2021-09-03.
# (86/4474) Volatility of residual return of 300066.SZ in 2021-09-03 is 1.0252530994487787.
# (87/4474) Volatility of residual return of 603338.SH in 2021-09-03 is 0.922197405646095.
# (88/4474) Volatility of residual return of 002915.SZ in 2021-09-03 is 1.0451614969405598.
# (89/4474) Volatility of residual return of 300999.SZ in 2021-09-03 is 1.1339086864016217.
# (90/4474) Volatility of residual return of 600007.SH in 2021-09-03 is 1.091175052340707.
# (91/4474) Volatility of residual return of 300347.SZ in 2021-09-03 is 0.9559841511103553.
# (92/4474) Volatility of residual return of 600318.SH in 2021-09-03 is 0.9776933337586695.
# (93/4474) Volatility of residual return of 000584.SZ in 2021-09-03 is 1.0647176703546846.
# (94/4474) Volatility of residual return of 603033.SH in 2021-09-03 is 1.0950928507603992.
# (95/4474) Volatility of residual return of 600601.SH in 2021-09-03 is 1.0918038029488057.
# (96/4474) Volatility of residual return of 300482.SZ in 2021-09-03 is 1.0301310405293298.
# (97/4474) Volatility of residual return of 603408.SH in 2021-09-03 is 1.0792536183609815.
# (98/4474) Volatility of residual return of 300700.SZ in 2021-09-03 is 1.013468114884625.
# (99/4474) Volatility of residual return of 000062.SZ in 2021-09-03 is 1.0545240351781942.
# (100/4474) Volatility of residual return of 603179.SH in 2021-09-03 is 1.0535908155304674.
# (101/4474) Volatility of residual return of 000797.SZ in 2021-09-03 is 1.0774659774055784.
# (102/4474) Volatility of residual return of 688200.SH in 2021-09-03 is 1.0419200890558897.
# (103/4474) Volatility of residual return of 002297.SZ in 2021-09-03 is 1.041440783130858.
# (104/4474) Volatility of residual return of 603848.SH in 2021-09-03 is 1.0945195433087336.
# (105/4474) 600891.SH has inadequate records till 2021-09-03.
# (106/4474) Volatility of residual return of 603520.SH in 2021-09-03 is 1.0296795435849457.
# (107/4474) Volatility of residual return of 000600.SZ in 2021-09-03 is 1.084634132312212.
# (108/4474) Volatility of residual return of 300851.SZ in 2021-09-03 is 1.0803569119194567.
# (109/4474) Volatility of residual return of 300479.SZ in 2021-09-03 is 1.0840186013228457.
# (110/4474) 600978.SH has inadequate records till 2021-09-03.
# (111/4474) Volatility of residual return of 605299.SH in 2021-09-03 is 1.1001308326616142.
# (112/4474) Volatility of residual return of 605228.SH in 2021-09-03 is 1.084653543779899.
# (113/4474) Volatility of residual return of 300487.SZ in 2021-09-03 is 1.0444428623385908.
# (114/4474) 688329.SH has inadequate records till 2021-09-03.
# (115/4474) Volatility of residual return of 600897.SH in 2021-09-03 is 1.0501910652492705.
# (116/4474) Volatility of residual return of 300281.SZ in 2021-09-03 is 1.0481651550658306.
# (117/4474) Volatility of residual return of 002466.SZ in 2021-09-03 is 1.012649107399139.
# (118/4474) Volatility of residual return of 002445.SZ in 2021-09-03 is 1.0970728602879918.
# (119/4474) Volatility of residual return of 002489.SZ in 2021-09-03 is 1.0332876561997841.
# (120/4474) Volatility of residual return of 002630.SZ in 2021-09-03 is 1.0591435163793617.
# (121/4474) 001211.SZ has inadequate records till 2021-09-03.
# (122/4474) Volatility of residual return of 605055.SH in 2021-09-03 is 1.107288004309339.
# (123/4474) Volatility of residual return of 002052.SZ in 2021-09-03 is 1.1047582607289796.
# (124/4474) Volatility of residual return of 002077.SZ in 2021-09-03 is 1.0894690447135416.
# (125/4474) Volatility of residual return of 002097.SZ in 2021-09-03 is 1.0161536785827785.
# (126/4474) Volatility of residual return of 300480.SZ in 2021-09-03 is 1.0746325226339086.
# (127/4474) Volatility of residual return of 002588.SZ in 2021-09-03 is 0.978170944525199.
# (128/4474) 300975.SZ has inadequate records till 2021-09-03.
# (129/4474) Volatility of residual return of 300915.SZ in 2021-09-03 is 1.098438280954322.
# (130/4474) Volatility of residual return of 688069.SH in 2021-09-03 is 1.0691608438040332.
# (131/4474) Volatility of residual return of 300332.SZ in 2021-09-03 is 1.0742049335149264.
# (132/4474) Volatility of residual return of 300859.SZ in 2021-09-03 is 1.1037805943025605.
# (133/4474) Volatility of residual return of 002371.SZ in 2021-09-03 is 1.0103803912809255.
# (134/4474) 605289.SH has inadequate records till 2021-09-03.
# (135/4474) Volatility of residual return of 300056.SZ in 2021-09-03 is 1.0936196336922328.
# (136/4474) Volatility of residual return of 002803.SZ in 2021-09-03 is 1.0321675656204976.
# (137/4474) Volatility of residual return of 002975.SZ in 2021-09-03 is 1.035490943194197.
# (138/4474) Volatility of residual return of 688466.SH in 2021-09-03 is 1.0723918339754481.
# (139/4474) Volatility of residual return of 002773.SZ in 2021-09-03 is 1.0708465326920256.
# (140/4474) Volatility of residual return of 300881.SZ in 2021-09-03 is 1.1070682320988412.
# (141/4474) Volatility of residual return of 601555.SH in 2021-09-03 is 1.022936225805759.
# (142/4474) Volatility of residual return of 603868.SH in 2021-09-03 is 1.041647794943623.
# (143/4474) Volatility of residual return of 300211.SZ in 2021-09-03 is 1.0577182256554167.
# (144/4474) Volatility of residual return of 600093.SH in 2021-09-03 is 1.0986960169383864.
# (145/4474) Volatility of residual return of 605337.SH in 2021-09-03 is 1.0667423787393524.
# (146/4474) Volatility of residual return of 000739.SZ in 2021-09-03 is 1.0354193820115116.
# (147/4474) Volatility of residual return of 000908.SZ in 2021-09-03 is 1.0814108280594878.
# (148/4474) Volatility of residual return of 600682.SH in 2021-09-03 is 1.0753043784411636.
# (149/4474) Volatility of residual return of 000960.SZ in 2021-09-03 is 1.0410306249284897.
# (150/4474) Volatility of residual return of 688135.SH in 2021-09-03 is 1.0879625175945573.
# (151/4474) Volatility of residual return of 688086.SH in 2021-09-03 is 1.056035726318635.
# (152/4474) Volatility of residual return of 603258.SH in 2021-09-03 is 1.0373441604332698.
# (153/4474) Volatility of residual return of 600119.SH in 2021-09-03 is 1.0861504398831767.
# (154/4474) Volatility of residual return of 300264.SZ in 2021-09-03 is 1.0808618179530545.
# (155/4474) Volatility of residual return of 601515.SH in 2021-09-03 is 1.079254946348392.
# (156/4474) Volatility of residual return of 601155.SH in 2021-09-03 is 1.0695811663827464.
# (157/4474) Volatility of residual return of 600114.SH in 2021-09-03 is 1.0182468124894442.
# (158/4474) Volatility of residual return of 000863.SZ in 2021-09-03 is 1.081355473798107.
# (159/4474) Volatility of residual return of 600986.SH in 2021-09-03 is 1.080332866667601.
# (160/4474) Volatility of residual return of 300885.SZ in 2021-09-03 is 1.1200754876974885.
# (161/4474) Volatility of residual return of 688004.SH in 2021-09-03 is 1.060294479657604.
# (162/4474) Volatility of residual return of 000547.SZ in 2021-09-03 is 1.0013739866931919.
# (163/4474) Volatility of residual return of 300612.SZ in 2021-09-03 is 1.0521719531217242.
# (164/4474) Volatility of residual return of 000403.SZ in 2021-09-03 is 1.0487925757958583.
# (165/4474) Volatility of residual return of 688029.SH in 2021-09-03 is 1.0514732462583547.
# (166/4474) Volatility of residual return of 002039.SZ in 2021-09-03 is 1.0561107030086014.
# (167/4474) Volatility of residual return of 300206.SZ in 2021-09-03 is 1.005727536147838.
# (168/4474) Volatility of residual return of 601599.SH in 2021-09-03 is 1.0993757681744112.
# (169/4474) Volatility of residual return of 002169.SZ in 2021-09-03 is 1.0442653903897146.
# (170/4474) Volatility of residual return of 300553.SZ in 2021-09-03 is 1.066730834453424.
# (171/4474) Volatility of residual return of 003005.SZ in 2021-09-03 is 1.1520604668365666.
# (172/4474) Volatility of residual return of 688183.SH in 2021-09-03 is 1.0800294562408648.
# (173/4474) Volatility of residual return of 605118.SH in 2021-09-03 is 1.0668384569213398.
# (174/4474) Volatility of residual return of 002363.SZ in 2021-09-03 is 1.04508593528927.
# (175/4474) Volatility of residual return of 002013.SZ in 2021-09-03 is 0.9816397329630329.
# (176/4474) Volatility of residual return of 002883.SZ in 2021-09-03 is 1.0125418812504419.
# (177/4474) Volatility of residual return of 002460.SZ in 2021-09-03 is 0.914063372310756.
# (178/4474) Volatility of residual return of 300478.SZ in 2021-09-03 is 1.0897682485829836.
# (179/4474) Volatility of residual return of 002171.SZ in 2021-09-03 is 0.9992602903789422.
# (180/4474) Volatility of residual return of 300017.SZ in 2021-09-03 is 1.0310538284587625.
# (181/4474) Volatility of residual return of 002344.SZ in 2021-09-03 is 1.003887887758006.
# (182/4474) Volatility of residual return of 002014.SZ in 2021-09-03 is 1.0238870207486674.
# (183/4474) Volatility of residual return of 002041.SZ in 2021-09-03 is 1.0483120197849645.
# (184/4474) Volatility of residual return of 300134.SZ in 2021-09-03 is 1.0875177338953972.
# (185/4474) Volatility of residual return of 300365.SZ in 2021-09-03 is 1.0594983540928073.
# (186/4474) Volatility of residual return of 601688.SH in 2021-09-03 is 0.9154632818464582.
# (187/4474) Volatility of residual return of 002147.SZ in 2021-09-03 is 1.1007004206071833.
# (188/4474) Volatility of residual return of 002879.SZ in 2021-09-03 is 1.0777350365615885.
# (189/4474) Volatility of residual return of 002389.SZ in 2021-09-03 is 0.9710989097427388.
# (190/4474) Volatility of residual return of 600735.SH in 2021-09-03 is 1.0759173425262782.
# (191/4474) Volatility of residual return of 600877.SH in 2021-09-03 is 1.0734357174207743.
# (192/4474) Volatility of residual return of 002017.SZ in 2021-09-03 is 1.079440254220108.
# (193/4474) Volatility of residual return of 600106.SH in 2021-09-03 is 1.0657837829145749.
# (194/4474) Volatility of residual return of 000869.SZ in 2021-09-03 is 1.0449893832244286.
# (195/4474) Volatility of residual return of 002136.SZ in 2021-09-03 is 1.0200924291104816.
# (196/4474) 688733.SH has inadequate records till 2021-09-03.
# (197/4474) Volatility of residual return of 300402.SZ in 2021-09-03 is 1.0767382418527824.
# (198/4474) Volatility of residual return of 300705.SZ in 2021-09-03 is 1.043124164938759.
# (199/4474) Volatility of residual return of 603126.SH in 2021-09-03 is 1.0862420994177384.
# (200/4474) Volatility of residual return of 603988.SH in 2021-09-03 is 1.0638437677744919.
# (201/4474) Volatility of residual return of 600265.SH in 2021-09-03 is 1.10564618785097.
# (202/4474) Volatility of residual return of 600275.SH in 2021-09-03 is 1.1052402196166193.
# (203/4474) Volatility of residual return of 300674.SZ in 2021-09-03 is 1.0390360896377073.
# (204/4474) Volatility of residual return of 300002.SZ in 2021-09-03 is 1.0505476245039511.
# (205/4474) Volatility of residual return of 002091.SZ in 2021-09-03 is 0.9941603777014552.
# (206/4474) Volatility of residual return of 000822.SZ in 2021-09-03 is 1.0524542694112222.
# (207/4474) Volatility of residual return of 300684.SZ in 2021-09-03 is 1.0269676350527963.
# (208/4474) Volatility of residual return of 002991.SZ in 2021-09-03 is 1.0384085602880901.
# (209/4474) Volatility of residual return of 600933.SH in 2021-09-03 is 1.0119054744594236.
# (210/4474) 605296.SH has inadequate records till 2021-09-03.
# (211/4474) Volatility of residual return of 000001.SZ in 2021-09-03 is 1.0161897284042272.
# (212/4474) Volatility of residual return of 600232.SH in 2021-09-03 is 1.0203723167026468.
# (213/4474) Volatility of residual return of 002895.SZ in 2021-09-03 is 1.0574537015314287.
# (214/4474) Volatility of residual return of 300569.SZ in 2021-09-03 is 1.0354112711884313.
# (215/4474) Volatility of residual return of 300608.SZ in 2021-09-03 is 1.0901867458560746.
# (216/4474) Volatility of residual return of 002045.SZ in 2021-09-03 is 1.0165654816185923.
# (217/4474) Volatility of residual return of 000060.SZ in 2021-09-03 is 1.0310669384942133.
# (218/4474) Volatility of residual return of 300554.SZ in 2021-09-03 is 1.0423671415256353.
# (219/4474) Volatility of residual return of 300481.SZ in 2021-09-03 is 0.9646791251700616.
# (220/4474) Volatility of residual return of 002095.SZ in 2021-09-03 is 1.0680040107056452.
# (221/4474) Volatility of residual return of 600146.SH in 2021-09-03 is 1.1063476179596494.
# (222/4474) Volatility of residual return of 603359.SH in 2021-09-03 is 1.0336074724317847.
# (223/4474) Volatility of residual return of 002113.SZ in 2021-09-03 is 1.0986120251012321.
# (224/4474) Volatility of residual return of 000935.SZ in 2021-09-03 is 1.073496923781758.
# (225/4474) Volatility of residual return of 601952.SH in 2021-09-03 is 1.019074369289862.
# (226/4474) Volatility of residual return of 300071.SZ in 2021-09-03 is 1.0973299913849013.
# (227/4474) Volatility of residual return of 300912.SZ in 2021-09-03 is 1.1118777471128483.
# (228/4474) Volatility of residual return of 600157.SH in 2021-09-03 is 1.104070062616026.
# (229/4474) Volatility of residual return of 603663.SH in 2021-09-03 is 1.043887825832228.
# (230/4474) Volatility of residual return of 600390.SH in 2021-09-03 is 0.9965465204892265.
# (231/4474) Volatility of residual return of 601377.SH in 2021-09-03 is 0.9763905558979876.
# (232/4474) Volatility of residual return of 600325.SH in 2021-09-03 is 1.07971795303068.
# (233/4474) Volatility of residual return of 002313.SZ in 2021-09-03 is 1.0425596840486182.
# (234/4474) Volatility of residual return of 002925.SZ in 2021-09-03 is 1.0290657471244007.
# (235/4474) Volatility of residual return of 688578.SH in 2021-09-03 is 1.0852263418922887.
# (236/4474) Volatility of residual return of 600566.SH in 2021-09-03 is 1.0240792161682706.
# (237/4474) Volatility of residual return of 000603.SZ in 2021-09-03 is 0.983872645733317.
# (238/4474) Volatility of residual return of 300647.SZ in 2021-09-03 is 1.0599986546598188.
# (239/4474) Volatility of residual return of 600010.SH in 2021-09-03 is 1.085368842526427.
# (240/4474) Volatility of residual return of 601500.SH in 2021-09-03 is 1.0499471913762097.
# (241/4474) Volatility of residual return of 603518.SH in 2021-09-03 is 1.0853921283847279.
# (242/4474) Volatility of residual return of 002125.SZ in 2021-09-03 is 1.0401321998732043.
# (243/4474) Volatility of residual return of 600708.SH in 2021-09-03 is 1.0785656303154108.
# (244/4474) 605589.SH has inadequate records till 2021-09-03.
# (245/4474) Volatility of residual return of 600266.SH in 2021-09-03 is 1.0889339881084334.
# (246/4474) Volatility of residual return of 300502.SZ in 2021-09-03 is 1.0164647438464633.
# (247/4474) Volatility of residual return of 600227.SH in 2021-09-03 is 1.0965900221015308.
# (248/4474) Volatility of residual return of 603386.SH in 2021-09-03 is 1.082815696403523.
# (249/4474) Volatility of residual return of 000711.SZ in 2021-09-03 is 1.089394268058821.
# (250/4474) Volatility of residual return of 002721.SZ in 2021-09-03 is 1.1001685117660673.
# (251/4474) 300970.SZ has inadequate records till 2021-09-03.
# (252/4474) Volatility of residual return of 600393.SH in 2021-09-03 is 1.0969010215068644.
# (253/4474) Volatility of residual return of 600026.SH in 2021-09-03 is 1.0691266282052043.
# (254/4474) Volatility of residual return of 688377.SH in 2021-09-03 is 1.0199767935427337.
# (255/4474) Volatility of residual return of 002798.SZ in 2021-09-03 is 1.04016577178422.
# (256/4474) Volatility of residual return of 002318.SZ in 2021-09-03 is 1.038979543815584.
# (257/4474) Volatility of residual return of 002375.SZ in 2021-09-03 is 1.0695635389869547.
# (258/4474) Volatility of residual return of 600960.SH in 2021-09-03 is 1.0418778050185231.
# (259/4474) Volatility of residual return of 600118.SH in 2021-09-03 is 0.9752844013310871.
# (260/4474) Volatility of residual return of 688590.SH in 2021-09-03 is 1.1218069104152886.
# (261/4474) Volatility of residual return of 000913.SZ in 2021-09-03 is 1.0683960661048113.
# (262/4474) 300362.SZ has inadequate records till 2021-09-03.
# (263/4474) Volatility of residual return of 600850.SH in 2021-09-03 is 0.9985248491135378.
# (264/4474) Volatility of residual return of 002023.SZ in 2021-09-03 is 1.0249117287585512.
# (265/4474) Volatility of residual return of 000048.SZ in 2021-09-03 is 1.038143154476616.
# (266/4474) Volatility of residual return of 603916.SH in 2021-09-03 is 0.9703440752731184.
# (267/4474) Volatility of residual return of 688286.SH in 2021-09-03 is 1.0146919208910063.
# (268/4474) Volatility of residual return of 300628.SZ in 2021-09-03 is 0.9854771293304789.
# (269/4474) Volatility of residual return of 300378.SZ in 2021-09-03 is 1.0398801789581196.
# (270/4474) Volatility of residual return of 600838.SH in 2021-09-03 is 1.058226334155535.
# (271/4474) Volatility of residual return of 300492.SZ in 2021-09-03 is 1.0624480387724673.
# (272/4474) Volatility of residual return of 601258.SH in 2021-09-03 is 1.10562891476049.
# (273/4474) Volatility of residual return of 300357.SZ in 2021-09-03 is 1.0136900541019949.
# (274/4474) Volatility of residual return of 300107.SZ in 2021-09-03 is 1.0471385705159195.
# (275/4474) Volatility of residual return of 300639.SZ in 2021-09-03 is 1.0302264858689447.
# (276/4474) Volatility of residual return of 600509.SH in 2021-09-03 is 1.0642154064440885.
# (277/4474) Volatility of residual return of 300240.SZ in 2021-09-03 is 1.0647642714395904.
# (278/4474) Volatility of residual return of 688357.SH in 2021-09-03 is 1.0708875648712166.
# (279/4474) Volatility of residual return of 002830.SZ in 2021-09-03 is 1.0817942038729373.
# (280/4474) 300953.SZ has inadequate records till 2021-09-03.
# (281/4474) Volatility of residual return of 600497.SH in 2021-09-03 is 1.0647714309344212.
# (282/4474) Volatility of residual return of 002494.SZ in 2021-09-03 is 1.0348063274484094.
# (283/4474) Volatility of residual return of 603903.SH in 2021-09-03 is 1.044822799251823.
# (284/4474) Volatility of residual return of 002354.SZ in 2021-09-03 is 1.0985985538458678.
# (285/4474) Volatility of residual return of 600609.SH in 2021-09-03 is 1.0713971331366405.
# (286/4474) Volatility of residual return of 000166.SZ in 2021-09-03 is 0.9884009238228869.
# (287/4474) Volatility of residual return of 688218.SH in 2021-09-03 is 1.022161607559381.
# (288/4474) Volatility of residual return of 003021.SZ in 2021-09-03 is 1.0890744859607113.
# (289/4474) Volatility of residual return of 600333.SH in 2021-09-03 is 1.0865785884738315.
# (290/4474) Volatility of residual return of 300483.SZ in 2021-09-03 is 1.0805414112872564.
# (291/4474) Volatility of residual return of 002625.SZ in 2021-09-03 is 1.0429492593560745.
# (292/4474) Volatility of residual return of 300387.SZ in 2021-09-03 is 1.0587211895353212.
# (293/4474) Volatility of residual return of 600795.SH in 2021-09-03 is 1.0865072284009654.
# (294/4474) Volatility of residual return of 000985.SZ in 2021-09-03 is 1.0811336992122675.
# (295/4474) Volatility of residual return of 300939.SZ in 2021-09-03 is 1.1178816810085963.
# (296/4474) 301013.SZ has inadequate records till 2021-09-03.
# (297/4474) Volatility of residual return of 300785.SZ in 2021-09-03 is 1.05083028871121.
# (298/4474) Volatility of residual return of 002248.SZ in 2021-09-03 is 1.0711914861336067.
# (299/4474) Volatility of residual return of 601366.SH in 2021-09-03 is 1.0948309458639984.
# (300/4474) Volatility of residual return of 601777.SH in 2021-09-03 is 1.0929467725788398.
# (301/4474) Volatility of residual return of 002574.SZ in 2021-09-03 is 1.0917895641738866.
# (302/4474) Volatility of residual return of 600282.SH in 2021-09-03 is 1.0773247139263877.
# (303/4474) Volatility of residual return of 002683.SZ in 2021-09-03 is 1.0162566787388814.
# (304/4474) Volatility of residual return of 002198.SZ in 2021-09-03 is 1.1076895393781359.
# (305/4474) Volatility of residual return of 002533.SZ in 2021-09-03 is 1.0681498669216964.
# (306/4474) Volatility of residual return of 000661.SZ in 2021-09-03 is 0.9886215321128667.
# (307/4474) Volatility of residual return of 000718.SZ in 2021-09-03 is 1.0684005437177262.
# (308/4474) Volatility of residual return of 601606.SH in 2021-09-03 is 1.0918394950233434.
# (309/4474) Volatility of residual return of 600172.SH in 2021-09-03 is 1.0744881007905298.
# (310/4474) Volatility of residual return of 603197.SH in 2021-09-03 is 1.0318270137510117.
# (311/4474) 605287.SH has inadequate records till 2021-09-03.
# (312/4474) Volatility of residual return of 603077.SH in 2021-09-03 is 1.0984080723315626.
# (313/4474) Volatility of residual return of 002910.SZ in 2021-09-03 is 1.0727475162298121.
# (314/4474) Volatility of residual return of 300042.SZ in 2021-09-03 is 1.0755835683831572.
# (315/4474) 001210.SZ has inadequate records till 2021-09-03.
# (316/4474) Volatility of residual return of 002503.SZ in 2021-09-03 is 1.0993210610306878.
# (317/4474) Volatility of residual return of 300092.SZ in 2021-09-03 is 1.0313895850682069.
# (318/4474) Volatility of residual return of 600998.SH in 2021-09-03 is 1.0864336863326727.
# (319/4474) Volatility of residual return of 000611.SZ in 2021-09-03 is 1.0940273553280757.
# (320/4474) Volatility of residual return of 002237.SZ in 2021-09-03 is 1.0714985333652423.
# (321/4474) Volatility of residual return of 002309.SZ in 2021-09-03 is 1.0986524081516178.
# (322/4474) Volatility of residual return of 002892.SZ in 2021-09-03 is 1.0656123603003143.
# (323/4474) Volatility of residual return of 000422.SZ in 2021-09-03 is 1.089361562647673.
# (324/4474) Volatility of residual return of 002463.SZ in 2021-09-03 is 1.0335109415115988.
# (325/4474) Volatility of residual return of 000786.SZ in 2021-09-03 is 0.9827558126962231.
# (326/4474) Volatility of residual return of 600798.SH in 2021-09-03 is 1.0623288139269684.
# (327/4474) Volatility of residual return of 603515.SH in 2021-09-03 is 1.0085844504025956.
# (328/4474) Volatility of residual return of 002430.SZ in 2021-09-03 is 1.0283620036283205.
# (329/4474) Volatility of residual return of 688560.SH in 2021-09-03 is 1.1167395513691907.
# (330/4474) Volatility of residual return of 601998.SH in 2021-09-03 is 1.0717357627867152.
# (331/4474) 688662.SH has inadequate records till 2021-09-03.
# (332/4474) Volatility of residual return of 300746.SZ in 2021-09-03 is 1.0445534440904771.
# (333/4474) Volatility of residual return of 603829.SH in 2021-09-03 is 1.075250040618803.
# (334/4474) Volatility of residual return of 600080.SH in 2021-09-03 is 1.1049233836384094.
# (335/4474) Volatility of residual return of 002395.SZ in 2021-09-03 is 1.0440119483722667.
# (336/4474) 601156.SH has inadequate records till 2021-09-03.
# (337/4474) Volatility of residual return of 601878.SH in 2021-09-03 is 0.9672379535668517.
# (338/4474) 605089.SH has inadequate records till 2021-09-03.
# (339/4474) Volatility of residual return of 002261.SZ in 2021-09-03 is 1.0510130311158907.
# (340/4474) Volatility of residual return of 300100.SZ in 2021-09-03 is 1.0887981214212925.
# (341/4474) Volatility of residual return of 603906.SH in 2021-09-03 is 1.027224663033054.
# (342/4474) Volatility of residual return of 002222.SZ in 2021-09-03 is 1.047767006748879.
# (343/4474) Volatility of residual return of 601686.SH in 2021-09-03 is 1.1070993220850285.
# (344/4474) Volatility of residual return of 603320.SH in 2021-09-03 is 1.0462101314018228.
# (345/4474) Volatility of residual return of 300689.SZ in 2021-09-03 is 1.0592212142131774.
# (346/4474) Volatility of residual return of 688085.SH in 2021-09-03 is 0.9878156414516945.
# (347/4474) Volatility of residual return of 300275.SZ in 2021-09-03 is 1.0466045555296621.
# (348/4474) Volatility of residual return of 600698.SH in 2021-09-03 is 1.052758685234756.
# (349/4474) Volatility of residual return of 605005.SH in 2021-09-03 is 1.1120048335948038.
# (350/4474) Volatility of residual return of 300196.SZ in 2021-09-03 is 1.007440963634627.
# (351/4474) Volatility of residual return of 300484.SZ in 2021-09-03 is 1.0297959254067943.
# (352/4474) 300984.SZ has inadequate records till 2021-09-03.
# (353/4474) Volatility of residual return of 002308.SZ in 2021-09-03 is 1.059442324517185.
# (354/4474) Volatility of residual return of 002409.SZ in 2021-09-03 is 1.0090445450908285.
# (355/4474) Volatility of residual return of 000712.SZ in 2021-09-03 is 1.0041555455352802.
# (356/4474) Volatility of residual return of 002727.SZ in 2021-09-03 is 1.0136411448886269.
# (357/4474) Volatility of residual return of 600776.SH in 2021-09-03 is 1.074542496686749.
# (358/4474) Volatility of residual return of 603200.SH in 2021-09-03 is 1.0693999943571673.
# (359/4474) Volatility of residual return of 600816.SH in 2021-09-03 is 1.115525275936332.
# (360/4474) Volatility of residual return of 600456.SH in 2021-09-03 is 0.9407990032152419.
# (361/4474) Volatility of residual return of 300022.SZ in 2021-09-03 is 1.0769502159268651.
# (362/4474) Volatility of residual return of 600238.SH in 2021-09-03 is 1.0795238004537624.
# (363/4474) Volatility of residual return of 002275.SZ in 2021-09-03 is 1.036493781582164.
# (364/4474) Volatility of residual return of 300857.SZ in 2021-09-03 is 1.0558695334820563.
# (365/4474) Volatility of residual return of 600692.SH in 2021-09-03 is 1.0563113182749444.
# (366/4474) Volatility of residual return of 688155.SH in 2021-09-03 is 1.0640642373005709.
# (367/4474) Volatility of residual return of 688165.SH in 2021-09-03 is 1.0417568133977146.
# (368/4474) Volatility of residual return of 601929.SH in 2021-09-03 is 1.0575547263291685.
# (369/4474) Volatility of residual return of 000338.SZ in 2021-09-03 is 0.9520735288137059.
# (370/4474) Volatility of residual return of 002833.SZ in 2021-09-03 is 1.0487907284224685.
# (371/4474) Volatility of residual return of 603538.SH in 2021-09-03 is 1.0448985741951218.
# (372/4474) Volatility of residual return of 601163.SH in 2021-09-03 is 0.9861019932084893.
# (373/4474) Volatility of residual return of 603700.SH in 2021-09-03 is 1.030465911042689.
# (374/4474) Volatility of residual return of 002514.SZ in 2021-09-03 is 1.0866679410561186.
# (375/4474) Volatility of residual return of 300221.SZ in 2021-09-03 is 1.0426720414530026.
# (376/4474) Volatility of residual return of 300045.SZ in 2021-09-03 is 1.053596596929827.
# (377/4474) Volatility of residual return of 603300.SH in 2021-09-03 is 1.1021890894708009.
# (378/4474) Volatility of residual return of 300842.SZ in 2021-09-03 is 1.0480938834494893.
# (379/4474) Volatility of residual return of 688233.SH in 2021-09-03 is 1.07036274662113.
# (380/4474) Volatility of residual return of 600724.SH in 2021-09-03 is 1.04622197616276.
# (381/4474) Volatility of residual return of 603915.SH in 2021-09-03 is 1.0125736007895583.
# (382/4474) Volatility of residual return of 000861.SZ in 2021-09-03 is 1.0791252013859645.
# (383/4474) Volatility of residual return of 002755.SZ in 2021-09-03 is 1.0584805489644953.
# (384/4474) Volatility of residual return of 300724.SZ in 2021-09-03 is 1.0320052499161931.
# (385/4474) Volatility of residual return of 688186.SH in 2021-09-03 is 1.067952807379179.
# (386/4474) Volatility of residual return of 603507.SH in 2021-09-03 is 1.0637056887066099.
# (387/4474) Volatility of residual return of 002429.SZ in 2021-09-03 is 1.0012211869131544.
# (388/4474) Volatility of residual return of 300570.SZ in 2021-09-03 is 1.0767259037758856.
# (389/4474) Volatility of residual return of 600008.SH in 2021-09-03 is 1.0755490442690465.
# (390/4474) Volatility of residual return of 002611.SZ in 2021-09-03 is 1.0604415506248195.
# (391/4474) Volatility of residual return of 300828.SZ in 2021-09-03 is 1.0487466115437867.
# (392/4474) Volatility of residual return of 002194.SZ in 2021-09-03 is 1.0396469399010186.
# (393/4474) Volatility of residual return of 300265.SZ in 2021-09-03 is 1.102439904467596.
# (394/4474) Volatility of residual return of 002391.SZ in 2021-09-03 is 0.940665086478207.
# (395/4474) 688667.SH has inadequate records till 2021-09-03.
# (396/4474) Volatility of residual return of 003001.SZ in 2021-09-03 is 1.062741963623291.
# (397/4474) Volatility of residual return of 600179.SH in 2021-09-03 is 1.1032762202015765.
# (398/4474) Volatility of residual return of 002832.SZ in 2021-09-03 is 1.0777983970781253.
# (399/4474) Volatility of residual return of 002047.SZ in 2021-09-03 is 1.0855907351575242.
# (400/4474) Volatility of residual return of 688096.SH in 2021-09-03 is 1.039836884929501.
# (401/4474) Volatility of residual return of 603918.SH in 2021-09-03 is 1.0670769113509897.
# (402/4474) Volatility of residual return of 300179.SZ in 2021-09-03 is 1.0726352787429312.
# (403/4474) Volatility of residual return of 603713.SH in 2021-09-03 is 1.0231425967775778.
# (404/4474) Volatility of residual return of 603698.SH in 2021-09-03 is 1.0696988760523545.
# (405/4474) Volatility of residual return of 300923.SZ in 2021-09-03 is 1.136813699106838.
# (406/4474) Volatility of residual return of 600753.SH in 2021-09-03 is 1.0876125805235404.
# (407/4474) Volatility of residual return of 688505.SH in 2021-09-03 is 1.036774749639588.
# (408/4474) Volatility of residual return of 603311.SH in 2021-09-03 is 1.0665350832844953.
# (409/4474) Volatility of residual return of 003006.SZ in 2021-09-03 is 1.0919117314367817.
# (410/4474) Volatility of residual return of 002881.SZ in 2021-09-03 is 1.0703822722760636.
# (411/4474) Volatility of residual return of 300109.SZ in 2021-09-03 is 1.0384686321288739.
# (412/4474) Volatility of residual return of 300735.SZ in 2021-09-03 is 1.0593682637990778.
# (413/4474) Volatility of residual return of 605008.SH in 2021-09-03 is 1.0890484727240821.
# (414/4474) Volatility of residual return of 300537.SZ in 2021-09-03 is 1.051572014633555.
# (415/4474) Volatility of residual return of 600876.SH in 2021-09-03 is 1.0283800873687705.
# (416/4474) Volatility of residual return of 300673.SZ in 2021-09-03 is 1.0114554264292368.
# (417/4474) 300774.SZ has inadequate records till 2021-09-03.
# (418/4474) Volatility of residual return of 002118.SZ in 2021-09-03 is 1.08566126670404.
# (419/4474) Volatility of residual return of 603332.SH in 2021-09-03 is 1.0973714718711103.
# (420/4474) Volatility of residual return of 600322.SH in 2021-09-03 is 1.0813963075997008.
# (421/4474) Volatility of residual return of 605377.SH in 2021-09-03 is 1.1055802843897826.
# (422/4474) Volatility of residual return of 603001.SH in 2021-09-03 is 1.0525271068935294.
# (423/4474) Volatility of residual return of 300921.SZ in 2021-09-03 is 1.1327727395330984.
# (424/4474) Volatility of residual return of 600428.SH in 2021-09-03 is 1.0672376791667106.
# (425/4474) Volatility of residual return of 600004.SH in 2021-09-03 is 1.0754295659883046.
# (426/4474) Volatility of residual return of 300626.SZ in 2021-09-03 is 1.0329272577448692.
# (427/4474) Volatility of residual return of 688065.SH in 2021-09-03 is 1.0400807814696007.
# (428/4474) Volatility of residual return of 600956.SH in 2021-09-03 is 1.0802916067069968.
# (429/4474) Volatility of residual return of 603596.SH in 2021-09-03 is 1.009225437567379.
# (430/4474) Volatility of residual return of 600543.SH in 2021-09-03 is 1.0599883132419186.
# (431/4474) Volatility of residual return of 600521.SH in 2021-09-03 is 1.0200636531914307.
# (432/4474) Volatility of residual return of 300342.SZ in 2021-09-03 is 1.0716354822362613.
# (433/4474) Volatility of residual return of 000002.SZ in 2021-09-03 is 1.071516123890764.
# (434/4474) Volatility of residual return of 603042.SH in 2021-09-03 is 1.0495908299819585.
# (435/4474) Volatility of residual return of 000063.SZ in 2021-09-03 is 1.0017737555546575.
# (436/4474) Volatility of residual return of 600742.SH in 2021-09-03 is 0.9655139089021192.
# (437/4474) Volatility of residual return of 600664.SH in 2021-09-03 is 1.0809502692968145.
# (438/4474) Volatility of residual return of 002374.SZ in 2021-09-03 is 1.0842929605994946.
# (439/4474) Volatility of residual return of 688215.SH in 2021-09-03 is 1.1106684641454503.
# (440/4474) Volatility of residual return of 300568.SZ in 2021-09-03 is 1.0119288578833008.
# (441/4474) Volatility of residual return of 688399.SH in 2021-09-03 is 1.073629273386888.
# (442/4474) 300997.SZ has inadequate records till 2021-09-03.
# (443/4474) Volatility of residual return of 002046.SZ in 2021-09-03 is 1.0280098956561472.
# (444/4474) Volatility of residual return of 300187.SZ in 2021-09-03 is 1.086326002534045.
# (445/4474) Volatility of residual return of 603855.SH in 2021-09-03 is 1.0465941558152891.
# (446/4474) Volatility of residual return of 300144.SZ in 2021-09-03 is 1.0874108674386325.
# (447/4474) Volatility of residual return of 600661.SH in 2021-09-03 is 1.0588767657557612.
# (448/4474) Volatility of residual return of 002012.SZ in 2021-09-03 is 1.0340594032433887.
# (449/4474) Volatility of residual return of 300676.SZ in 2021-09-03 is 1.0205948511247998.
# (450/4474) Volatility of residual return of 603378.SH in 2021-09-03 is 1.0453231925164912.
# (451/4474) Volatility of residual return of 600305.SH in 2021-09-03 is 0.9798757283802377.
# (452/4474) Volatility of residual return of 605001.SH in 2021-09-03 is 1.0510371903731175.
# (453/4474) Volatility of residual return of 605288.SH in 2021-09-03 is 1.0408423554530397.
# (454/4474) Volatility of residual return of 002383.SZ in 2021-09-03 is 1.0842974721598615.
# (455/4474) Volatility of residual return of 300075.SZ in 2021-09-03 is 1.0425740445242195.
# (456/4474) Volatility of residual return of 000561.SZ in 2021-09-03 is 1.0543628140676413.
# (457/4474) Volatility of residual return of 002706.SZ in 2021-09-03 is 1.0387279884981473.
# (458/4474) Volatility of residual return of 300412.SZ in 2021-09-03 is 1.0322279281942912.
# (459/4474) Volatility of residual return of 688408.SH in 2021-09-03 is 1.03741539637767.
# (460/4474) Volatility of residual return of 001979.SZ in 2021-09-03 is 1.0730878504177344.
# (461/4474) Volatility of residual return of 605151.SH in 2021-09-03 is 1.1060952370308432.
# (462/4474) Volatility of residual return of 002709.SZ in 2021-09-03 is 0.9540995031092396.
# (463/4474) Volatility of residual return of 600959.SH in 2021-09-03 is 1.0787271545034378.
# (464/4474) Volatility of residual return of 300380.SZ in 2021-09-03 is 1.0510191787565593.
# (465/4474) Volatility of residual return of 601816.SH in 2021-09-03 is 1.064704787476836.
# (466/4474) Volatility of residual return of 000528.SZ in 2021-09-03 is 0.9290596007760991.
# (467/4474) Volatility of residual return of 688678.SH in 2021-09-03 is 1.103786784508039.
# (468/4474) Volatility of residual return of 300848.SZ in 2021-09-03 is 1.0759704537942745.
# (469/4474) Volatility of residual return of 600158.SH in 2021-09-03 is 1.06621255415128.
# (470/4474) Volatility of residual return of 603650.SH in 2021-09-03 is 1.0199334369868163.
# (471/4474) Volatility of residual return of 300318.SZ in 2021-09-03 is 1.0736031753117858.
# (472/4474) Volatility of residual return of 002956.SZ in 2021-09-03 is 1.030208417876554.
# (473/4474) 301023.SZ has inadequate records till 2021-09-03.
# (474/4474) Volatility of residual return of 300417.SZ in 2021-09-03 is 1.0724379848795116.
# (475/4474) Volatility of residual return of 002542.SZ in 2021-09-03 is 1.064448147653758.
# (476/4474) Volatility of residual return of 300208.SZ in 2021-09-03 is 1.0901869828917214.
# (477/4474) Volatility of residual return of 000530.SZ in 2021-09-03 is 1.0785905295373197.
# (478/4474) Volatility of residual return of 002271.SZ in 2021-09-03 is 0.9868597765337698.
# (479/4474) 688305.SH has inadequate records till 2021-09-03.
# (480/4474) Volatility of residual return of 603882.SH in 2021-09-03 is 0.9700634523470294.
# (481/4474) Volatility of residual return of 300911.SZ in 2021-09-03 is 1.1082701995629014.
# (482/4474) Volatility of residual return of 000717.SZ in 2021-09-03 is 1.074107046356034.
# (483/4474) Volatility of residual return of 002553.SZ in 2021-09-03 is 1.0940522518394773.
# (484/4474) Volatility of residual return of 300085.SZ in 2021-09-03 is 1.0128933835142049.
# (485/4474) Volatility of residual return of 002823.SZ in 2021-09-03 is 1.0579985319307592.
# (486/4474) Volatility of residual return of 600261.SH in 2021-09-03 is 1.0454860890365867.
# (487/4474) Volatility of residual return of 002618.SZ in 2021-09-03 is 1.0817916860564631.
# (488/4474) Volatility of residual return of 600366.SH in 2021-09-03 is 1.0545427333486885.
# (489/4474) Volatility of residual return of 300367.SZ in 2021-09-03 is 1.088927751140989.
# (490/4474) Volatility of residual return of 000672.SZ in 2021-09-03 is 1.0307707839598992.
# (491/4474) Volatility of residual return of 002440.SZ in 2021-09-03 is 1.0301738455085718.
# (492/4474) Volatility of residual return of 002446.SZ in 2021-09-03 is 1.0635795617057444.
# (493/4474) Volatility of residual return of 603076.SH in 2021-09-03 is 1.065586036363108.
# (494/4474) Volatility of residual return of 688520.SH in 2021-09-03 is 1.0310437029612867.
# (495/4474) Volatility of residual return of 300465.SZ in 2021-09-03 is 1.073413532293057.
# (496/4474) Volatility of residual return of 601689.SH in 2021-09-03 is 0.9476301439324474.
# (497/4474) Volatility of residual return of 601872.SH in 2021-09-03 is 1.0659326572609131.
# (498/4474) Volatility of residual return of 603183.SH in 2021-09-03 is 1.0638406275401355.
# (499/4474) Volatility of residual return of 688687.SH in 2021-09-03 is 1.101885358227604.
# (500/4474) Volatility of residual return of 002102.SZ in 2021-09-03 is 1.0954895917018599.
# (501/4474) Volatility of residual return of 300917.SZ in 2021-09-03 is 1.1158733731314432.
# (502/4474) Volatility of residual return of 603045.SH in 2021-09-03 is 1.0562003664421118.
# (503/4474) Volatility of residual return of 300709.SZ in 2021-09-03 is 1.0114799833112957.
# (504/4474) Volatility of residual return of 603896.SH in 2021-09-03 is 1.086677223781892.
# (505/4474) Volatility of residual return of 002937.SZ in 2021-09-03 is 1.041689571854629.
# (506/4474) Volatility of residual return of 601336.SH in 2021-09-03 is 0.9924890784449152.
# (507/4474) 688328.SH has inadequate records till 2021-09-03.
# (508/4474) Volatility of residual return of 688013.SH in 2021-09-03 is 1.1165249683705356.
# (509/4474) Volatility of residual return of 600812.SH in 2021-09-03 is 1.0692364134060977.
# (510/4474) Volatility of residual return of 002897.SZ in 2021-09-03 is 1.0554925680553178.
# (511/4474) Volatility of residual return of 605100.SH in 2021-09-03 is 1.0059973956403725.
# (512/4474) Volatility of residual return of 000545.SZ in 2021-09-03 is 1.049778018357436.
# (513/4474) Volatility of residual return of 300772.SZ in 2021-09-03 is 1.051434121896465.
# (514/4474) Volatility of residual return of 600461.SH in 2021-09-03 is 1.0693555228062406.
# (515/4474) Volatility of residual return of 603178.SH in 2021-09-03 is 1.0682876794148974.
# (516/4474) Volatility of residual return of 300879.SZ in 2021-09-03 is 1.1049833612746212.
# (517/4474) Volatility of residual return of 002658.SZ in 2021-09-03 is 1.0843445801815432.
# (518/4474) Volatility of residual return of 300649.SZ in 2021-09-03 is 1.0858078842924035.
# (519/4474) Volatility of residual return of 000607.SZ in 2021-09-03 is 1.0837968138034377.
# (520/4474) Volatility of residual return of 603883.SH in 2021-09-03 is 1.0168610031517082.
# (521/4474) Volatility of residual return of 300726.SZ in 2021-09-03 is 0.9953543198078532.
# (522/4474) 301051.SZ has inadequate records till 2021-09-03.
# (523/4474) Volatility of residual return of 600493.SH in 2021-09-03 is 1.0185891558487516.
# (524/4474) Volatility of residual return of 603069.SH in 2021-09-03 is 1.088126429285203.
# (525/4474) Volatility of residual return of 600025.SH in 2021-09-03 is 1.0945641413493397.
# (526/4474) Volatility of residual return of 000538.SZ in 2021-09-03 is 0.9432396515155989.
# (527/4474) Volatility of residual return of 600683.SH in 2021-09-03 is 1.0844747303172924.
# (528/4474) Volatility of residual return of 002592.SZ in 2021-09-03 is 1.1020064995612888.
# (529/4474) Volatility of residual return of 000989.SZ in 2021-09-03 is 1.027455991689385.
# (530/4474) Volatility of residual return of 603608.SH in 2021-09-03 is 1.0715593039585651.
# (531/4474) Volatility of residual return of 688356.SH in 2021-09-03 is 1.1549547619236054.
# (532/4474) Volatility of residual return of 603803.SH in 2021-09-03 is 1.0419214791718274.
# (533/4474) Volatility of residual return of 600230.SH in 2021-09-03 is 1.0474289098696685.
# (534/4474) Volatility of residual return of 002578.SZ in 2021-09-03 is 1.0479414258986148.
# (535/4474) Volatility of residual return of 002605.SZ in 2021-09-03 is 1.021227022414177.
# (536/4474) Volatility of residual return of 002510.SZ in 2021-09-03 is 1.0555552450304242.
# (537/4474) Volatility of residual return of 300171.SZ in 2021-09-03 is 1.0070930289789646.
# (538/4474) Volatility of residual return of 600482.SH in 2021-09-03 is 0.9969617699246845.
# (539/4474) Volatility of residual return of 600370.SH in 2021-09-03 is 1.0655239851682718.
# (540/4474) Volatility of residual return of 600203.SH in 2021-09-03 is 1.0831926168478667.
# ...
# (4314/4474) Volatility of daily excessive return of 002912.SZ in 2021-09-03 is 0.0001670588146427699.
# (4315/4474) Volatility of daily excessive return of 688686.SH in 2021-09-03 is 0.0020853902355796685.
# (4316/4474) Volatility of daily excessive return of 688330.SH in 2021-09-03 is 0.0001844869584659154.
# (4317/4474) Volatility of daily excessive return of 605058.SH in 2021-09-03 is 0.00017186383201372242.
# (4318/4474) 688670.SH has inadequate records till 2021-09-03.
# (4319/4474) Volatility of daily excessive return of 601568.SH in 2021-09-03 is 8.815709434268825e-05.
# (4320/4474) Volatility of daily excessive return of 002348.SZ in 2021-09-03 is 0.00033296860145209755.
# (4321/4474) Volatility of daily excessive return of 002730.SZ in 2021-09-03 is 0.0002125430579729012.
# (4322/4474) Volatility of daily excessive return of 600650.SH in 2021-09-03 is 4.620112551135706e-05.
# (4323/4474) Volatility of daily excessive return of 002714.SZ in 2021-09-03 is 0.00025924233280448115.
# (4324/4474) Volatility of daily excessive return of 300427.SZ in 2021-09-03 is 0.0003256592437115979.
# (4325/4474) Volatility of daily excessive return of 300877.SZ in 2021-09-03 is 0.00018911771475670015.
# (4326/4474) Volatility of daily excessive return of 000709.SZ in 2021-09-03 is 9.63225109169217e-05.
# (4327/4474) Volatility of daily excessive return of 002186.SZ in 2021-09-03 is 7.861192362165748e-05.
# (4328/4474) Volatility of daily excessive return of 600987.SH in 2021-09-03 is 4.128282424413067e-05.
# (4329/4474) Volatility of daily excessive return of 600826.SH in 2021-09-03 is 4.5004746297268516e-05.
# (4330/4474) Volatility of daily excessive return of 002208.SZ in 2021-09-03 is 0.00019660951612841007.
# (4331/4474) Volatility of daily excessive return of 002696.SZ in 2021-09-03 is 7.169403210433659e-05.
# (4332/4474) Volatility of daily excessive return of 002063.SZ in 2021-09-03 is 0.00010816993949187293.
# (4333/4474) Volatility of daily excessive return of 688078.SH in 2021-09-03 is 0.000730569721147022.
# (4334/4474) Volatility of daily excessive return of 603388.SH in 2021-09-03 is 5.273677560075723e-05.
# (4335/4474) Volatility of daily excessive return of 600862.SH in 2021-09-03 is 0.00028209976627471383.
# (4336/4474) Volatility of daily excessive return of 600730.SH in 2021-09-03 is 0.00016372421706127316.
# (4337/4474) Volatility of daily excessive return of 000965.SZ in 2021-09-03 is 3.843242668369999e-05.
# (4338/4474) Volatility of daily excessive return of 603922.SH in 2021-09-03 is 0.00013207017089677175.
# (4339/4474) Volatility of daily excessive return of 300031.SZ in 2021-09-03 is 0.00035106850816369597.
# (4340/4474) Volatility of daily excessive return of 000680.SZ in 2021-09-03 is 8.394133317586627e-05.
# (4341/4474) Volatility of daily excessive return of 002980.SZ in 2021-09-03 is 9.981266570445213e-05.
# (4342/4474) Volatility of daily excessive return of 603659.SH in 2021-09-03 is 0.0004318015758059617.
# (4343/4474) Volatility of daily excessive return of 002165.SZ in 2021-09-03 is 9.20963029918739e-05.
# (4344/4474) Volatility of daily excessive return of 000780.SZ in 2021-09-03 is 0.0001160344648777972.
# (4345/4474) Volatility of daily excessive return of 002819.SZ in 2021-09-03 is 0.0003952439647640715.
# (4346/4474) Volatility of daily excessive return of 688116.SH in 2021-09-03 is 0.0005643070663013556.
# (4347/4474) Volatility of daily excessive return of 600537.SH in 2021-09-03 is 0.0002415152460061015.
# (4348/4474) Volatility of daily excessive return of 002981.SZ in 2021-09-03 is 0.00010043587457686627.
# (4349/4474) Volatility of daily excessive return of 300813.SZ in 2021-09-03 is 0.0007317858596490019.
# (4350/4474) Volatility of daily excessive return of 300720.SZ in 2021-09-03 is 0.00037150742840576863.
# (4351/4474) Volatility of daily excessive return of 600567.SH in 2021-09-03 is 6.565576533263648e-05.
# (4352/4474) Volatility of daily excessive return of 300020.SZ in 2021-09-03 is 0.0002075700066868721.
# (4353/4474) Volatility of daily excessive return of 002369.SZ in 2021-09-03 is 0.0003195421460490327.
# (4354/4474) Volatility of daily excessive return of 603527.SH in 2021-09-03 is 0.0001722171683751787.
# (4355/4474) Volatility of daily excessive return of 300246.SZ in 2021-09-03 is 0.00015419286284987528.
# (4356/4474) Volatility of daily excessive return of 600653.SH in 2021-09-03 is 7.242217618623408e-05.
# (4357/4474) Volatility of daily excessive return of 002783.SZ in 2021-09-03 is 0.00015795621999620713.
# (4358/4474) Volatility of daily excessive return of 002404.SZ in 2021-09-03 is 0.00010595926915892482.
# (4359/4474) Volatility of daily excessive return of 002128.SZ in 2021-09-03 is 0.00021359533510746133.
# (4360/4474) Volatility of daily excessive return of 600919.SH in 2021-09-03 is 0.00011325368126242104.
# (4361/4474) Volatility of daily excessive return of 688508.SH in 2021-09-03 is 0.0006184882642744154.
# (4362/4474) Volatility of daily excessive return of 000056.SZ in 2021-09-03 is 0.0003103021465086173.
# (4363/4474) Volatility of daily excessive return of 600657.SH in 2021-09-03 is 3.4007192938855405e-05.
# (4364/4474) Volatility of daily excessive return of 601211.SH in 2021-09-03 is 8.964794654045209e-05.
# (4365/4474) Volatility of daily excessive return of 002872.SZ in 2021-09-03 is 7.29679291484686e-05.
# (4366/4474) Volatility of daily excessive return of 300826.SZ in 2021-09-03 is 0.00013034830477979574.
# (4367/4474) Volatility of daily excessive return of 300659.SZ in 2021-09-03 is 0.00032839062997196697.
# (4368/4474) Volatility of daily excessive return of 603733.SH in 2021-09-03 is 0.00021135795309941812.
# (4369/4474) Volatility of daily excessive return of 000629.SZ in 2021-09-03 is 0.00030089232158759036.
# (4370/4474) Volatility of daily excessive return of 600556.SH in 2021-09-03 is 0.0001464964612751378.
# (4371/4474) Volatility of daily excessive return of 002276.SZ in 2021-09-03 is 0.00012467286364304425.
# (4372/4474) Volatility of daily excessive return of 300494.SZ in 2021-09-03 is 0.0002099463813674628.
# (4373/4474) Volatility of daily excessive return of 002130.SZ in 2021-09-03 is 0.00020483199948240446.
# (4374/4474) Volatility of daily excessive return of 300384.SZ in 2021-09-03 is 0.00035890720035198993.
# (4375/4474) 688659.SH has inadequate records till 2021-09-03.
# (4376/4474) Volatility of daily excessive return of 600153.SH in 2021-09-03 is 2.9085431346936712e-05.
# (4377/4474) Volatility of daily excessive return of 600112.SH in 2021-09-03 is 0.0004719630722125253.
# (4378/4474) Volatility of daily excessive return of 601177.SH in 2021-09-03 is 6.942005825518705e-05.
# (4379/4474) Volatility of daily excessive return of 300843.SZ in 2021-09-03 is 0.00031206327679607706.
# (4380/4474) Volatility of daily excessive return of 000707.SZ in 2021-09-03 is 0.00028946415868554774.
# (4381/4474) Volatility of daily excessive return of 300597.SZ in 2021-09-03 is 0.00015863826899292628.
# (4382/4474) Volatility of daily excessive return of 000004.SZ in 2021-09-03 is 0.00038103697151618045.
# (4383/4474) Volatility of daily excessive return of 601021.SH in 2021-09-03 is 0.0001568142658077768.
# (4384/4474) 688799.SH has inadequate records till 2021-09-03.
# (4385/4474) Volatility of daily excessive return of 603727.SH in 2021-09-03 is 0.00015726625778499505.
# (4386/4474) Volatility of daily excessive return of 603500.SH in 2021-09-03 is 0.00015600065464626612.
# (4387/4474) Volatility of daily excessive return of 603980.SH in 2021-09-03 is 3.6784477515165334e-05.
# (4388/4474) Volatility of daily excessive return of 600600.SH in 2021-09-03 is 0.00021451600146155437.
# (4389/4474) Volatility of daily excessive return of 300618.SZ in 2021-09-03 is 0.00031705944813345874.
# (4390/4474) Volatility of daily excessive return of 002180.SZ in 2021-09-03 is 0.00016402780194228286.
# (4391/4474) Volatility of daily excessive return of 000838.SZ in 2021-09-03 is 0.000194201928146709.
# (4392/4474) Volatility of daily excessive return of 601908.SH in 2021-09-03 is 0.0004040549182700102.
# (4393/4474) Volatility of daily excessive return of 300733.SZ in 2021-09-03 is 0.00029281085100837944.
# (4394/4474) Volatility of daily excessive return of 300621.SZ in 2021-09-03 is 0.00038009038699765324.
# (4395/4474) 688597.SH has inadequate records till 2021-09-03.
# (4396/4474) Volatility of daily excessive return of 603058.SH in 2021-09-03 is 0.00010719073964538523.
# (4397/4474) Volatility of daily excessive return of 688158.SH in 2021-09-03 is 0.0001404800301866731.
# (4398/4474) Volatility of daily excessive return of 600298.SH in 2021-09-03 is 0.0001583676074261658.
# (4399/4474) Volatility of daily excessive return of 603948.SH in 2021-09-03 is 6.573824606791245e-05.
# (4400/4474) Volatility of daily excessive return of 300363.SZ in 2021-09-03 is 0.00046329442037197464.
# (4401/4474) Volatility of daily excessive return of 002838.SZ in 2021-09-03 is 0.00013025734299124646.
# (4402/4474) Volatility of daily excessive return of 300133.SZ in 2021-09-03 is 6.342496497532509e-05.
# (4403/4474) Volatility of daily excessive return of 000735.SZ in 2021-09-03 is 5.72722340308891e-05.
# (4404/4474) Volatility of daily excessive return of 688196.SH in 2021-09-03 is 0.0003411099718841152.
# (4405/4474) 300976.SZ has inadequate records till 2021-09-03.
# (4406/4474) 688383.SH has inadequate records till 2021-09-03.
# (4407/4474) Volatility of daily excessive return of 603335.SH in 2021-09-03 is 7.330820511347628e-05.
# (4408/4474) Volatility of daily excessive return of 002583.SZ in 2021-09-03 is 6.93105633074906e-05.
# (4409/4474) 688195.SH has inadequate records till 2021-09-03.
# (4410/4474) Volatility of daily excessive return of 002983.SZ in 2021-09-03 is 0.0002326617107222218.
# (4411/4474) Volatility of daily excessive return of 600611.SH in 2021-09-03 is 2.444048600407841e-05.
# (4412/4474) Volatility of daily excessive return of 002079.SZ in 2021-09-03 is 0.00034755409580961683.
# (4413/4474) Volatility of daily excessive return of 002345.SZ in 2021-09-03 is 0.0001551387778988144.
# (4414/4474) 688161.SH has inadequate records till 2021-09-03.
# (4415/4474) Volatility of daily excessive return of 605399.SH in 2021-09-03 is 0.00035615843449369854.
# (4416/4474) Volatility of daily excessive return of 600535.SH in 2021-09-03 is 5.201285962572921e-05.
# (4417/4474) Volatility of daily excessive return of 600622.SH in 2021-09-03 is 4.1179645542746394e-05.
# (4418/4474) Volatility of daily excessive return of 603690.SH in 2021-09-03 is 0.0004810595559901837.
# (4419/4474) Volatility of daily excessive return of 300588.SZ in 2021-09-03 is 0.0010307523773492747.
# (4420/4474) Volatility of daily excessive return of 603605.SH in 2021-09-03 is 0.00016803443457936713.
# (4421/4474) Volatility of daily excessive return of 600301.SH in 2021-09-03 is 0.0001715275436131799.
# (4422/4474) Volatility of daily excessive return of 002861.SZ in 2021-09-03 is 0.0001264840633079313.
# (4423/4474) 301031.SZ has inadequate records till 2021-09-03.
# (4424/4474) Volatility of daily excessive return of 300112.SZ in 2021-09-03 is 0.0002766938861360464.
# (4425/4474) Volatility of daily excessive return of 600993.SH in 2021-09-03 is 0.00029228332930980827.
# (4426/4474) Volatility of daily excessive return of 600309.SH in 2021-09-03 is 0.00017303815049519324.
# (4427/4474) Volatility of daily excessive return of 002855.SZ in 2021-09-03 is 5.8189713542589626e-05.
# (4428/4474) Volatility of daily excessive return of 000678.SZ in 2021-09-03 is 4.781468736408728e-05.
# (4429/4474) Volatility of daily excessive return of 002064.SZ in 2021-09-03 is 0.00023051113271443488.
# (4430/4474) Volatility of daily excessive return of 300899.SZ in 2021-09-03 is 0.0008981829545916583.
# (4431/4474) Volatility of daily excessive return of 600821.SH in 2021-09-03 is 0.00020818221985425436.
# (4432/4474) Volatility of daily excessive return of 603369.SH in 2021-09-03 is 0.00025965155630648955.
# (4433/4474) Volatility of daily excessive return of 603839.SH in 2021-09-03 is 0.00012643341897368042.
# (4434/4474) Volatility of daily excessive return of 688081.SH in 2021-09-03 is 0.0003543847376556005.
# (4435/4474) Volatility of daily excessive return of 000997.SZ in 2021-09-03 is 0.00013350628657512545.
# (4436/4474) Volatility of daily excessive return of 603629.SH in 2021-09-03 is 0.00028818031787404693.
# (4437/4474) Volatility of daily excessive return of 300920.SZ in 2021-09-03 is 0.0003704882100907133.
# (4438/4474) Volatility of daily excessive return of 300027.SZ in 2021-09-03 is 7.369194343510604e-05.
# (4439/4474) Volatility of daily excessive return of 002887.SZ in 2021-09-03 is 0.0001136357514508523.
# (4440/4474) Volatility of daily excessive return of 688008.SH in 2021-09-03 is 0.0002471337062828034.
# (4441/4474) 688191.SH has inadequate records till 2021-09-03.
# (4442/4474) Volatility of daily excessive return of 688628.SH in 2021-09-03 is 0.005174849797473091.
# (4443/4474) Volatility of daily excessive return of 600104.SH in 2021-09-03 is 9.207714418281363e-05.
# (4444/4474) Volatility of daily excessive return of 002926.SZ in 2021-09-03 is 5.5353187633106125e-05.
# (4445/4474) Volatility of daily excessive return of 600597.SH in 2021-09-03 is 7.818567089724637e-05.
# (4446/4474) Volatility of daily excessive return of 600909.SH in 2021-09-03 is 6.512799211256096e-05.
# (4447/4474) Volatility of daily excessive return of 300038.SZ in 2021-09-03 is 0.000350132460901269.
# (4448/4474) Volatility of daily excessive return of 688536.SH in 2021-09-03 is 0.0007595547345715458.
# (4449/4474) Volatility of daily excessive return of 688600.SH in 2021-09-03 is 0.00019828158785086233.
# (4450/4474) Volatility of daily excessive return of 600292.SH in 2021-09-03 is 0.0002796688846607516.
# (4451/4474) 003042.SZ has inadequate records till 2021-09-03.
# (4452/4474) Volatility of daily excessive return of 603013.SH in 2021-09-03 is 0.00022849963912350313.
# (4453/4474) Volatility of daily excessive return of 601727.SH in 2021-09-03 is 0.00017933801739874542.
# (4454/4474) Volatility of daily excessive return of 300389.SZ in 2021-09-03 is 0.00041681791753287524.
# (4455/4474) Volatility of daily excessive return of 000778.SZ in 2021-09-03 is 6.118803679025031e-05.
# (4456/4474) Volatility of daily excessive return of 600107.SH in 2021-09-03 is 0.0001238233615260308.
# (4457/4474) 688517.SH has inadequate records till 2021-09-03.
# (4458/4474) Volatility of daily excessive return of 603603.SH in 2021-09-03 is 0.0003265838418475961.
# (4459/4474) Volatility of daily excessive return of 001872.SZ in 2021-09-03 is 4.513418612019827e-05.
# (4460/4474) Volatility of daily excessive return of 688598.SH in 2021-09-03 is 0.0006006572258410939.
# (4461/4474) Volatility of daily excessive return of 603607.SH in 2021-09-03 is 0.00010625682014656512.
# (4462/4474) Volatility of daily excessive return of 600598.SH in 2021-09-03 is 6.056963745548256e-05.
# (4463/4474) Volatility of daily excessive return of 600129.SH in 2021-09-03 is 0.00023296305328422142.
# (4464/4474) Volatility of daily excessive return of 002419.SZ in 2021-09-03 is 6.444977794527158e-05.
# (4465/4474) Volatility of daily excessive return of 600811.SH in 2021-09-03 is 7.540941935558179e-05.
# (4466/4474) Volatility of daily excessive return of 600425.SH in 2021-09-03 is 0.00013434834803228377.
# (4467/4474) Volatility of daily excessive return of 300750.SZ in 2021-09-03 is 0.0002671094068274675.
# (4468/4474) Volatility of daily excessive return of 002614.SZ in 2021-09-03 is 0.00018450804985306347.
# (4469/4474) Volatility of daily excessive return of 002291.SZ in 2021-09-03 is 0.0002958289907277646.
# (4470/4474) 688800.SH has inadequate records till 2021-09-03.
# (4471/4474) Volatility of daily excessive return of 300875.SZ in 2021-09-03 is 0.0002422582698439337.
# (4472/4474) Volatility of daily excessive return of 601808.SH in 2021-09-03 is 0.00014474159357628482.
# (4473/4474) Volatility of daily excessive return of 603963.SH in 2021-09-03 is 0.000102702218729134.
# (4474/4474) Volatility of daily excessive return of 002748.SZ in 2021-09-03 is 0.00018683265931212427.

# %%
RV_df.to_csv('../database/data/RV_demo.csv', index=False)

# %% [markdown]
# ## Scrach Paper

# %%
with open('../config/config.json', 'r') as f:
    config = json.load(f)
con = pymysql.connect(**config)
cur = con.cursor()

# sqlalchemy
alchemy_str = 'mysql+pymysql://' + config['user'] + ':' + config[
    'password'] + '@' + config['host'] + ':' + str(
        config['port']) + '/' + config['database']
alchemy_engine = sqlalchemy.create_engine(alchemy_str)

# %%
cal_query = '''
            SELECT DISTINCT trade_date
            FROM asset_return;
            '''
cal_df = pd.read_sql_query(cal_query, con=alchemy_engine)
cal_df = cal_df.sort_values(by=['trade_date'], ascending=False)


def _get_latest_date(lag=0):  # Get latest date in database BARRA
    date_dt = cal_df.iloc[lag, 0]
    date = date_dt.strftime('%Y-%m-%d')
    print(f'Lastest date(lag = {lag}): {date}')
    return date
